# %%
from langchain_openai import OpenAIEmbeddings
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from langchain_text_splitters import TokenTextSplitter
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from dotenv import load_dotenv
import json

# Load the environment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# # Load the data

# %%
train_directory = "/Users/ritikgupta/Downloads/train/train/"
test_directory = "/Users/ritikgupta/Downloads/test/test/"
# loader = DirectoryLoader(directory, glob='**/*.json', show_progress=True, loader_cls=TextLoader)
# data_full_text = loader.load()
# len(data_full_text)

def get_data_list(directory):
    data_full_text = []
    text_and_geo=[]
    for filename in os.listdir(directory):
        if filename.endswith('.json'):
            with open(os.path.join(directory, filename), 'r') as json_file:
                data = json.load(json_file)
                # 
                if data:
                    ocr_entries = data['0']['ocr']
                    concatenated_text = '\n'.join(ocr_entry['text'] for ocr_entry in ocr_entries)
                    for ocr in ocr_entries:
                   
                       geo_data = [(ocr['geo'][0] + ocr['geo'][2]) / 2, (ocr['geo'][1] + ocr['geo'][3]) / 2]  # Calculate center of bounding box
                        
                     text_and_geo.append(f"Geo: {geo_data}")  # Append geo data to the text
                    concatenated_text = '\n'.join(text_and_geo)  # Join text and geo data
                    data_full_text.append({"source": filename, "text": concatenated_text})
                    
                   
                    
                    
                else:
                    print(f"File {filename} is empty")         
                
    return data_full_text
# Out:
#   File <tokenize>:22
#     text_and_geo.append(f"Geo: {geo_data}")  # Append geo data to the text
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
train_text = get_data_list(train_directory)

test_text = get_data_list(test_directory)
for i in test_text:
    print(i['text'])
# Out:
# File 1e2b7953be7636ba815864fadc095e1e.pdf.CACHE.json is empty
# File 0956af3ce4abc3a87a76b8a36901de4d.pdf.CACHE.json is empty
# File 145a525ff411c5447d9ed585c2409e74.pdf.CACHE.json is empty
# File 248c4da26eb1bdc419058d104fc02e51.JPG.CACHE.json is empty
# File 208c74fd9000ce0678ef0ae481ce7aaa.pdf.CACHE.json is empty
# File 088c1bfd401dfd81480ce0c857aee199.pdf.CACHE.json is empty
# File 1f6968f4cc9e2d0b41c86645711782c4.jpg.CACHE.json is empty
# File 1fe28d53546729bf195cc4b0d1d19c14.JPG.CACHE.json is empty
# Ayse Deli
# Am Schloß 9
# 35410 Hungen
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Kündigung der Rentenversicherung Nr. 53189
# Datum: 14.07.2015
# Verehrte Damen und Herren,
# leider muss ich Ihnen mit diesem Schreiben mitteilen, dass mein Ehemann Heinrich
# vergangenen Montag verstorben ist. Bitte heben Sie aus diesem Grund den oben
# genannten Vertrag auf. Ich übersende Ihnen Ende dieser Woche den
# Versicherungsschein sowie eine beglaubigte Sterbeurkunde.
# Den Auszahlungsbetrag möchten Sie bitte auf das Konto 0147258369, BLZ 10020030
# bei der Beispielbank Bielefeld erstatten.
# Freundliche Grüße
# Deli
# Depoteröffnungsantrag
# AS
# inkl. Altersvorsorge-Sparplan
# €€€
# Insiders
# Investment
# Die Depoteröffnung
# wurde vorab per Fax
# bzw. telefonisch an
# Insiders übermittelt.
# Depotinhaber
# Referenz-Nr: P 0185411
# Depotnummer
# X Herr
# Frau
# Vor- und Zuname
# FRANZ MUSTERMANN
# Geburtsdatum
# 15061968
# Ergänzung/Geburtsname
# ist der Antragsteller minderjährig, muß der
# Antrag von den gesetzlichen Vertretern (in
# der Regel beide Elternteile) unterschrieben
# Straße und Haus-Nr.
# werden. Die Eltern bevollmächtigen sich
# MUSTERWEG 7
# gegenseitig, als gesetzliche Vertreter des
# Minderjährigen den Depotinhaber allein zu
# vertreten.
# Land
# -
# DE
# 23456 MUSTERHAUSEN
# Ort
# Nationalität
# DEUTSCH
# Beruf
# ELEKTRIKER
# X selbst
# angest
# Steuerausländer
# Bei vom Wohnsitz abweichender Versandanschrift bitte separates Blatt beifügen.
# Gesetzliche/r Vertreter
# Her
# Frau
# Vor- und Zuname/Geburtsname des 1. gesetzlichen Vertreters (Mutter oder Vater)
# Geburtsdatum
# Vor- und Zuname/Geburtsname des 2. gesetzlichen Vertreters (Mutter oder Vater)
# Geb .- Datum 2. gesetzl. Vertr.
# Nationalität
# Beru
# selbst
# angest
# Steuerausländer
# Vollmacht für den Todesfall
# Keine Erbregelung; nach meinem Ableben ist folgende Person bevollmächtigt, über dieses Depot zu verfügen:
# Vor- und Zuname
# MARIA MUSTERMANN
# Geburtsdatum
# 27091969
# Ergänzung/Geburtsname
# SCHMIDT
# Straße und Haus-Nr.
# --
# MUSTERWEG 7
# Land
# PLZ
# DE
# 23456 MUSTERHAUSEN
# Ort
# Anlageauftrag
# Die Anlage soll in folgendem Sondervermögen erfolgen:
# [X] GenoAS: 1
# Ausgabeaufschlag: 3 % des Anteilwertes
# Verwaltungsvergütung: (max.) 1,5 % p. a. des börsentäglich festgestellten Inventarwertes, derzeit 0,8 % p. a.
# X Altersvorsorge-Sparplan
# Laufzeit des Anlageauftrages
# Jahre (mind. 18 Jahre) oder
# bis zur Vollendung des 65 Lebensjahres (mind. 60. Lebensjahr)
# Anlageplan:
# Ich wünsche eine regelmäßige Anlage des folgenden Geldbetrags
# EUR
# 100mind. EUR 50;
# erster Kauf zum
# 01012012
# letzter Kauf zum 31122032
# X monat.
# 2monatł.
# X jährl.
# 1/ jährl.
# jährlich
# einmaliger Anlageauftrag
# ] zusätzlicher Anlageauftrag zum Altersvorsorge-Sparplan
# Ich ermächtige Insiders Investment den Betrag in Höhe von EUR
# 100
# sofort (bei Antragseingang) einzuziehen.
# Bitte Feld „Einzugsermächtigung“ ausfüllen.
# 50/1/1/260
# ( ) 101.338.772-5
# --
# R+V Lebensversicherungs AG
# Taunusstr.1
# 65193 Wiesbaden
# Almsdorf, 14.11.96
# nonktion
# 2 7. NO: 135
# Betrifft:Versicherungsschein Nr.
# _Versicherungsnehmer:Jeannette
# -Allgemeine
# Sehr geehrte Damen und Herren,
# hiermit beantrage ich die vorläufige Stillegung meiner in Ihrem Hause abgeschlossenen
# Auf Grund einiger anderweitigen finanziellen Belastungen ist es mir nicht möglich den
# Versicherung.
# Beitragsverpflichtungen nachzukommen.
# Ich wiederrufe hiermit Ihre Einzugsermächtigung von meinem Konto.
# Mit freundlichen Grüßen
# Jeannette
# Versicherungsmakler AG
# Versicherungsmakler AG
# Zum sicheren Weg 99
# 89560 Berlin
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 17.04.2015
# Agentur-Nummer: 85480175+7049
# Gruppenunfall-Versicherung Nummer: 85289374568
# VN: Christian Beck, Vogelsanger Weg 119,50858 Köln
# Kundennummer 12387
# Sehr geehrter Herr Strauss,
# mit Dokument vom 02.04.2015 wurden wie von uns beantragt dem Vertrag die neuesten
# Bedingungen AUB 2100 zugrunde gelegt
# Bitte bestätigen Sie uns noch der guten Ordnung halber, dass
# » Invaliditätsleistung als Kapitalzahlung bis zum 70 Lebensjahr gewährt wird und
# » unsere Spezialbedingungen, die wir Ihnen überlassen haben, berücksichtigt worden sind.
# Ich bin ab 19.04.2015 im Urlaub; vielleicht könnten wir uns nach meiner Rückkehr ab 06.05.2015 kurz
# abstimmen.
# Mit freundlichen Grüßen
# Michael Müller
# Versicherungsmarkler AG
# Hinweis: Umschlag bitte aufbewahren, siehe Rückseite!
# Zugestellt am
# (Datum, ggf. Uhrzeit, Unterschrift)
# Deutsche Post
# 190820
# Förmliche Zustellung
# Weitersenden innerhalb des
# Aktenzeichen
# Bezirks des Amtsgerichts
# Bezirks des Landgerichts
# Inlands
# Bei der Zustellung zu beachtende Vermerke
# Ersatzzustellung ausgeschlossen
# Keine Ersatzzustellung an:
# Nicht durch Niederlegung zustellen
# Mit Angabe der Uhrzeit zustellen
# XEROX
# BEZAHLT 1 8. April 2010
# EINGEGANGEN 0 3. April 2010
# Vertragspartner
# HARD- UND SOFTWARELÖSUNGEN
# - ALLES RUND UMS BÜRO
# Norbert Weinkauff &
# Windstrasse 13
# 66955 PIRMASENS
# Telefon ( 0 63 31) 55 15-0
# Norbert Weinkauff GmbH · Postfach 2345 · 66931 Pirmasens
# Telefax ( 0 63 31) 55 15-30
# Insiders Technologies GmbH
# Verwaltung@Xerox-Pirmasens.de
# Brüsseler Str. 1
# www.xerox-pirmasens.de
# 67657 Kaiserslautern
# HRB 2387 Amtsgericht Pirmasens
# Umsatzsteuer ID-Nr .: DE 149601969
# Geschäftsführer: Norbert Weinkauff
# KR-435
# RECHNUNG
# Rechnungsdatum : 03.04.2010
# Seite
# ..
# Rechnungs-Nr.
# WV-61228
# 1
# Ihre Best .- Nr.
# Kunden-Nr.
# 11611
# Bezeichnung
# Menge
# E-Preis Euro
# Ges .- Preis Euro
# Modell
# WC Pro 423 PE
# Gerätenummer
# 2241351435
# Vertrags-Nummer:
# 1155
# Standort
# : Insiders Technologies GmbH, Brüsseler Str. 1,67657 Kaiserslautern
# Zähler 1 (S/W) - Abrechnungszeitraum von 01.01.2010 bis 31.03.2010
# Zählerstand alt:
# 80.467
# Zählerstand neu:
# 92.760
# Gefertigte Kopien:
# 12.293
# Freikopien:
# 6.000
# Netto-Kopien:
# 6.293
# Kopien für WC Pro 423 PE (1. Staffelpreis)
# 6.293
# 0,0148
# 93,14
# TEXT Norbert. Weinkruiff WY-61228
# (Kostenrechnung)
# SBM
# BETRAG
# Konto
# Gegenkonti Kostenstel'd
# 110,84
# 4930
# 70096
# geprüft durch
# A films.
# Datum:
# Warenwert Euro
# zzgl. 19% MwSt. Euro
# Gesamtbetrag Euro
# 93,14
# 17,70
# 110,84
# Zahlbar innerhalb v. 10 Tagen rein netto
# Rechnungsdatum ist gleich Lieferdatum
# Ohne eine weitere Zahlungsaufforderung tritt nach 30 Tagen
# Verzug ein (§288 Abs. 3 BGB)
# Sparkasse Südwestpfalz Pirmasens (BLZ 54250010) Kto .- Nr. 52191
# Drucken · Faxen · Scannen · Kopieren - Digital und farbig · Papier und Zubehör
# Riadh Schweitzer
# Detmolder Str. 2-4
# 51109 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 27.08.2013
# Betr.: Beitragsfreistellung meiner Lebensversicherung
# Nr.: 12345
# Guten Tag,
# Seit vergangenem Monat bin ich arbeitslos. Daher bitte ich Sie, o. a. Versicherung ruhend zu stellen
# (ist möglich nach Auskunft meines Beraters).
# Die zu zahlenden Beträge kann ich bei monatlicher Unterstützung (s. Kopie) nicht aufbringen. Sobald
# ich eine neue Stelle habe, möchte ich die Versicherung wieder aktivieren.
# Ich bitte um kurze schriftliche Bestätigung.
# Mit freundlichen Grüßen
# Riadh Schweitzer
# Sabine Kallmeyer, Im Bachgarten 60,50259 Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Donnerstag | 07/03/12
# betrifft: Lebensversicherung 789456
# Guten Tag,
# hiermit bitte ich Sie aus persönlichen Gründen meine o. g. Versicherung ab sofort beitragsfrei zu
# stellen.
# Freundliche Grüße
# Sabine Kallm.
# BUNDESREPUBLIK DEUTSCHLAND
# T22000129
# FEDERAL REPUBLIC OF GERMANY / REPUBLIQUE FEDERALE D'ALLEMAGNE
# PERSONALAUSWEIS
# Name/Surname/Nom
# IDENTITY CARD / CARTE D'IDENTITE
# MUSTERMANN
# GEB. GABLER
# Vornamen/Given names/Prénoms
# ERIKA
# Geburtstag/Date of birth/
# Staatsangehörigkeit/ Nationality/
# Date de naissance
# 12.08. 1964 DEUTSCH
# Geburtsort/Place of birth/Lieu de naissance
# BERLIN
# Gültig bis/Date of expiry/
# Date d'expiration
# 31.10.2020
# 938568
# Unterschrift der Inhaberin/des Inhabers -
# Signature of bearer - Signature de la titulaire/du titulaire
# Otto Naum GmbH - Versicherungsmakler
# Otto Naum GmbH - Versicherungsmakler
# Im Ruhrpott 23
# 56333 Essen
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Freitag, d. 06.11.2013,
# Vers. Nr. 64879
# Der Kunde meldet folgenden Schaden vom 03.11.2013 Uhrzeit ca. 16:10 Uhr.
# Schadensort: Im Bachgarten 61,50259 Puhlheim
# Geschädigte Person: Alexander Kallmeyer
# Schadenschilderung: Frau Sabine Kallmeyer und Sohn Alexander war zu Besuch bei Fam. Peschke.
# Der Hund sprang den Sohn an und hat in sein Designer-T-Shirt ein Loch gerissen. Wir bitten den
# Schaden in Höhe von 67,95€ zu ersetzen.
# Anbei erhalten Sie die Rechnung über das T-Shirt.
# Wir verleiben mit freundlichen Grüßen
# O. Naum
# RIADH SCHWEITZER
# DETMOLDER STR. 2-4
# 51109 KÖLN
# INSIDERS VERSICHERUNGEN
# BRÜSSELER STRAßE 100
# 67657 KAISERSLAUTERN
# MONTAG, DEN 16.12.2014
# MITTEILUNG ÜBER ADRESSÄNDERUNG
# GUTEN TAG,
# AB DEM 1.1.2015 LAUTET MEINE NEUE ANSCHRIFT:
# WIENKAMP 3
# 48308 SENDEN
# MEINE BANKVERBINDUNGEN BLEIBEN BIS AUF WEITERES ERHALTEN.
# MIT DEN BESTEN EMPFEHLUNGEN
# RIADH SCHWEITZER
# Sommer
# Hans Kallmeyer
# Im Bachgarten 60
# 50259 Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Pulheim
# Mitt ., d. 19.7.2012
# Lebensversicherung Nr. 9433385546
# Guten Tag,
# bitte teilen Sie mir zu meinem o.g. Lebensversicherungsvertrag den Rückkaufswert zum 01.09.2012
# sowie zum 01.10.2013 schriftlich mit.
# Vielen Dank.
# Hana Kallmayer
# Klaus-Peter Schmidt
# Rosenstraße 88
# 50733 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Mitt., d. 19.7.2012
# Betr .: Änderung der bezugsberechtigten Person im Todesfall
# Verehrte Damen und Herren,
# hiermit ändere ich die in meinem Versicherungsvertrag bestehende Bezugsberechtigung im
# Todesfall.
# Bezugsberechtigt soll sein mein Sohn David Jonathan.
# Die Bezugsberechtigung im Erlebensfall bleibt unverändert.
# Ich bitte um Ihre Bestätigung
# Mit freundlichen Grüßen
# K-P Schmidt
# Maximilian Müller
# Pariser Straße 19
# 67663 Kaiserslautern
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 17.04.2015
# Kündigung der Versicherung Nr. 8013001350
# Sehr geehrte Damen und Herren,
# hiermit kündige ich o.g. Vertrag zum nächstmöglichen Termin. Die
# Einzugsermächtigung von meinem Konto entziehe ich Ihnen zum gleichen Termin.
# Den Rückkaufwert einschließlich Gewinnen, bitte ich Sie auf mein Konto bei der
# Deutschen Bank Kaiserslautern zu überweisen.
# Mit freundlichen Grüßen
# Maxi Müller
# Riadh Schweitzer
# Detmolder Str. 2-4
# 51109 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Adressänderungsmitteilung
# Guten Tag,
# hiermit teile ich Ihnen, dass ich vom 19.05.2013 bis zum 21.05.2013 umziehe und meine
# neue Adresse ab 22.05.2013 wie folgt lautet:
# Zur Winkelgasse 78,51109 Köln
# Bitte stellen Sie meine Versicherungsverträge entsprechend um.
# Vielen Dank.
# Mit freundlichen Grüßen
# Schweitzer
# 00
# Kosmetikstudio Leberfleck
# 15.08.2010
# Versicherungs AG
# Akazienplatz 1
# 61611 Waghausen
# Betreff: Kontoänderung (Versicherungsnummer 2397497949)
# Sehr geehrte Damen und Herren,
# unsere Bankverbindung hat sich geändert. Bitte buchen Sie ab sofort von folgendem
# Konto ab:
# Volksbank Waghausen
# BLZ 87798124
# Konto 19727987
# Mit freundlichem Gruß,
# 6. Lebeglich
# Gregoria Leberfleck
# Pariser Str. 67 · 67657 Kaiserslautern · Telefon: (0631) 141515
# BUNDESREPUBLIK DEUTSCHLAND
# DE
# LO1XJ32R5
# FEDERAL REPUBLIC OF GERMANY/ RE-
# PERSONALAUSWEIS
# IDENTITY CARD | CARTE YSENTITE
# [a] Name/Surname/Nom
# [b] Geburtsname/Name at birth/Nom de naissance
# [a]MUSTERMANN
# DIGABLER
# Vornamen/Given names/Prénoms
# ERIKA
# TER
# Geburtstag/Date of birth/
# Staatsangehörigkeit/Nationality/
# Date de naissance
# Nationalite
# 12.08.1983 DEUTSCH
# Geburtsont/Place of birth/Lieu de naissance
# BERLIN
# Gültig bis/Date of expiry/
# Date d'expiration
# 01.08.2031
# 373081
# Krankenkasse bzw. Kostenträger
# Arbeitsunfähigkeits-
# 1
# bescheinigung
# Name, Vorname des Versicherten
# Lean
# 1 geb. amZ.86
# Erstbescheinigung
# Steinbecker Meile 115
# D 25364 Osterhorn
# Folgebescheinigung
# Kostenträgerkennung
# Versicherten-Nr ...
# P915118102
# Arzt-Nr.
# 769536755 30.03.10
# Arbeitsunfall, Arbeitsunfall-
# folgen, Berufskrankheit
# dem Durchgangsarzt
# zugewiesen
# 2420-29
# arbeitsunfähig seit
# voraussichtlich arbeitsunfähig
# 04.06.19
# bis einschließlich oder letzter
# Tag der Arbeitsunfähigkeit
# 1420.29
# festgestellt am
# Vertragsarztstempel / Unterschrift des Arztes
# Ausfertigung zur Vorlage beim Arbeitgeber
# Muster 1b (1.2016)
# 51345
# ·
# www.praxisformulare.de
# ·
# Ohm
# Print
# Consulting
# GmbH
# ·
# Freisenbergstr.
# 21.58513
# Lüdenscheid
# Sabine Kallmeyer, Im Bachgarten 60,50259 Pulheim
# Dienstag, den 09. Feb. 2012, Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Betr .: Versicherungsnr. 88460301-20
# Sehr geehrte Damen und Herren,
# bitte lösen Sie die o.g. Risikolebensversicherung zum 01.03.2012 auf.
# Vielen Dank.
# Mit freundlichen Grüßen
# Sabine x
# Landeshauptstadt
# Wiesbaden
# Am Bürgerring 67,68433 Wiesbaden
# Kreisverwaltungsreferat
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 17.04.2015
# Fahrzeug mit dem amtlichen Kennzeichen M-GP 308
# Eingetragener Halter: Bernd Karl Eicher
# Anzeige eingegangen am 11.04.15
# Bitte Folgendes vermerken:
# Neues Kennzeichen zugeteilt mit Halterwechsel
# X Fahrzeug vorübergehend stillgelegt am
# 3.4.2015
# Neue Versicherungsbestätigung liegt vor
# von Ihnen unter der Nr. K 85/40/100 7864
# für bisherigen Halter
# Mit den besten Empfehlungen
# Janja KJamile
# Im Auftrag Tanja Kranike, Verwaltungsfachangestellte Stadtverwaltung
# Landeshauptstadt Wiesbaden
# 230
# Zulassungsbescheinigung Teil I
# 140/4000 1
# (Fahrzeugschein)
# 15.07.2020 00052
# CZD000037.
# 29
# 1 P.2
# P.4
# 1827-1827
# KL-S-0-197/20-00033
# MI
# 191
# 4
# AC
# 4709-4709
# 1705-1705
# NT.
# WBA11DZ010FK03792
# 3 2
# 1440-1440
# G
# Europäische
# BMW
# 75
# 1
# Gemeinschaft
# D
# Bundesrepublik
# 13
# D.1.
# Deutschland
# 136
# 2225
# 2225
# F.2
# G3K
# F.1
# V.7
# -
# Cannerenersicro sa periorpauns . "act ( / Permiso de circulación. Parte /
# Osvědčení o registraci - Část | /Registreringsattest. Del 1 /
# 11DZ
# 1025
# 7.2
# 1290
# -
# Registreermistunnistus. Osa I / Aocw xchocoplac Ihororomeio Eyypoons.
# Mffpog1/ Registration certificata. Part 1 / Certificat d'immatriculation. Partle 1 /
# D.2
# IAW500BC
# 1025
# 8.2
# 1290
# 8.3
# Prometna cozvola | / Carta di circolazione. Parte | / Registracijas aplieciba.
# 8.1
# caja / Registracios ludijimas. I dalis / Forgalmi engedély. I. Rész / Certifikat
# 72
# 3000
# U.3
# 0 1
# ta Registrazzjoni. L-| Parti / Kentekenbewijs. Deel | / Dowód Rejestracyjny.
# -
# U.1
# U.2
# Część1 / Certificado de matricula. Parte |/ Certificat de inmatriculare Partoa 1 /
# 320d
# 1800 0.2
# 750
# -
# S.1
# Osvedcenie o evidencii: Cast' | / Prometno dovoljenje. Del 1 /
# D.3
# 0.1
# RekisterdiniEnd
# istus. Osa | / Registreringsbeviset. Del I
# 225/45 R18 95Y B
# A Amtliches Kennzeichen
# BAYER. MOT. WERKE-BMW
# 2
# 15.1
# KL A 2347
# Fz. z. Pers.bef.b. 8 Spl.
# 225/45 R18 95Y B
# 5.2
# Kombilimousine
# 15.3
# -
# C.1.1 Name oder Firmenname
# Insiders Technologies
# 715/2007*2018/1832AP
# Blau
# V.9
# 11
# 5
# GmbH
# EURO6; WLTP; AP; PI/CI; M, NI
# e1*2007/46*2017*02
# 14
# Hybr. Diesel/E
# 05. 02.2020
# C.1.2 Vorname(n)
# FU304524
# 0010 141 36AP
# 1995
# -
# 10
# 21.
# 7.278.2: +120 B. ANHANGEBETRIEB *WW. AHK LT. EGTG *ZU PZ/
# C.1.3 Anschrift
# 22
# Brüsseler Str. 1
# P4: ENTFÄLLTKW/30MIN; NENNLEISTUNG 2. 2KW*
# 67657 Kaiserslautern
# X
# Nächste HU
# (Monat und Jahr).
# Kaiserslautern
# 07/2023
# Datum:
# 15.07.2020
# C.Ac Der Inhaber der Zulassungsbescheinigung wird nicht als Eigentümer des
# Fahrzeugs ausgewiesen.
# ELIX
# DEUTSCHLAND
# BUNDESREPUBLIK DEUTSCHLAND
# LO1XXZK00
# DE
# FEDERAL REPHarIC OF GEEN, NY / REPUBLIQUE FEDERALE D'ALLEMAGNE
# PERSONALAUSWEIS
# IDENTITY CARD / CARTE D'IDENTITÉ
# [a] Name/Surname/Nom
# [b] Geburtsname/Name at birth/Nom de naissance
# [a]MUSTERMANN
# TIGABLER
# Vornamen/Given names/Prénoms
# ERIKA
# STER
# Geburtstag/Date of Birth/
# Date de naissance
# Staatsangehörigkeit/Nationality/
# Nationalité
# 12.08.1983 DEUTSCH
# Geburtsort/Place of birth/Lieu de naissanr
# BERLIN
# Gültig bis/Date of expiry/
# Date d'expiration
# 01.08.2031
# REINO DE ESPAÑA
# .ES
# DOCUMENTO NACIONAL DE IDENTIDAD
# 99999999R
# DNI 99999999R
# CAA000000
# APELLIDOS
# ESPAÑOLA
# ESPAÑOLA
# NOMBRE
# CARMEN
# SEXO
# NACIONALIDAD
# ESPECIMEN
# NACIMIENTO
# F
# ESP
# 01 01 1980
# EMISIÓN
# VALIDEZ
# 02 06 2021 02 06 2031
# NUM SOPORTE
# 020621
# CAA000000
# 987654
# NATIONAL IDENTITY CARD / DOCUMENTO NACIONAL IDENTIDAD
# Christian Beck, Vogelsanger Weg 119,50858 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 30. Jan. 2013, Köln
# Vertrag Nr.: 0000143
# Hiermit stelle ich den Vertrag zum nächsten Monatsbeginn beitragsfrei. Eine erteilte
# Einzugsermächtigung widerrufe ich ab diesem Termin.
# Meinen Arbeitgeber informiere ich entsprechend.
# Bitte senden Sie mir einen neuen Versicherungsschein zu.
# mit freundlichen Grüßen
# Chr. Beck
# Zulassungsbescheinigung Teil I
# 14.08.2013 - 0603 AKZ00162 8
# 2 1 2
# 125/6000 213
# (Fahrzeugschein]
# M1
# AF
# 4397-4494
# 1794
# -
# KL-S-0-226/13-00015
# WVGZZZ1TZEWO13818
# 1619-1694
# 1614
# Europäische
# D
# Bundesrepublik
# D VOLKSWAGEN, VW
# -
# 75
# -
# Gemeinschaft
# Deutschland
# 1T
# 154
# 2230
# 2230
# Parser, de circulación. Parte I / OuvedlEerd o registraci - Chat 1 /
# CTHBAF
# 1120
# 1170
# -
# Registration cerchcare. Pult I / Certihest d'wetmatriculation. Partie \ /
# FD7FD7AM0067MJS7N1VROS0
# Carta di croolazione. Parti i / Itripnitricjas splecitia. t. dale /
# 1120
# 1170
# -
# Cervejkac ta' Registrarzgors. L-1 Partı ) Kentekentewia. Deet 1/
# -
# u1 080
# 3750
# 3 070
# Dowod Rejestracysty. Część 1 / Corbisemin ne mat/okt. Parze i /
# Gaveocenie e ivuitnea, Cast 1/ Prometne dovoljenje, Deli ?
# TOURAN
# 1500
# 750
# 7
# 2
# VOLKSWAGEN-VW
# 205/50 R17 93V
# KL X343
# Fz.z.Pers.bef.b. 8 Spl.
# 205/50 R17 93V
# Mehrzweckfahrzeug
# -
# INSIDERS Technologies
# vs 715/2007*630/2012J
# GRAU
# 7
# GmbH
# EUROS ; J ; PI/ CI ; M, N1 I
# e1*2001/116*0211*32
# Benzin
# 25.04.2013
# K & EE816074
# 0001
# 35J0 1390
# TE
# -
# F.1/F.2:+35 u. 7.2/8.2:+50 b.Anhängebetrieb*0.1:1800 b
# Brüsseler Str. 1
# is 8% Steig .* techn.zul.Ges- Masse d. Zugkombination: 3765
# 67657 Kaiserslautern
# kg*Fzg.bei werkseitig monti erter AHK m.spez.Fahrdyn.St
# abi. Syst.f.Anh.Betr.f.Temp. 100 km/h gem.3.Aend.VO.z.9.
# Nachite HU
# Kaiserslautern
# Ausn.VO.z.STVO*techn.zul.Ge s-Masse d.Zugkombination an
# Monat und Parole
# 08.2016
# 14.08.2013
# 8% Steig.: 4065kg*ww.AHK lt .EGTG*
# C te De trusher der Zulesmangebescheinigung wird nicht als Eigentümer des
# Futraeijs ausgewiesen.
# (Raum får weitere amtlich zugelassenu Eintragungen?
# Die Angaben müson ständig den tatsächlichen Verhältnissen entsprechen.
# Weitere HU;
# Anderungen sind der zuständigen Zulassungshthdrde nach Maßigube der for dia
# Datum zu K.
# (7)
# Fahrzeugau asking geltenden Rechtsvorschriften anzuzeigen.
# Technisch zuanigo maximale Actalast/Masse je
# Achwyuppe in kg
# Bei Verauflerting des Fahrzeugs sind dem Erwerber gegen Empfangs-
# (7.1) Achot 1 bis 17.3) Achse 3
# bescheinigung die Zulassungsbescheinigung Tell I und Tell Il aussahandigen, Die
# Zulasugo maximale Achtlast in Zulassungemni!gladstaat
# Empfangsbescheinigung muis den Namen und die Anschrift des Erwerbart vo7-
# In ag
# Mandig enthalten und ct vom Verdulurer unverzüglich der Zulassungsbehdede
# (8.1. Aceso 1 bis (E 3) Achso ]
# Unterlassung der vergeschriebenen Meidenflichten (Abmeldung, Umschreibung
# 4101
# bhi Erwarb oder Umzug In einen anderen zulauungsbezirk, Meldung anderer
# Veränderungen) kann durch GeldouBe geahndet werden.
# Jauminhalt der Tanks bei Tarkfazereuune in
# Se Ceelast in An
# Bornichnung noe nationalen danssionsklasse
# Definition der Felder:
# Code zu V.9 oder (14)
# Bereifung
# Bezeichnung
# (15 1] auf Achse 1 liit (15.5) auf Achpe 3
# Detum der Entzulassing des Fanracugs
# Nummer der Zulattungubescheinigung Tall #
# Marke
# Typ:Variante/Versoil
# Langs 36 mm
# Brodo in dintt
# Hohe in sms
# FT
# Terbeisch culistige Gecambmasse in kg
# Sontlige Vermerke
# Batteriemagen und Aussaltmenn
# Masse des 35 Seidise befindeichon fahrzeugs in kg (Letrinasse)
# 4
# Datum dieter Zulassung
# Hinweis za Feld , 75.1) bis (HS. ]]:
# Fahr souritiques
# Andere als die angegebenen Baradunços können in Rahmen der quiligen
# Nummer der LE Typgenehmigung cder ABE
# Typ- oder binalawnentinund am fahrzeug angebracht werden, Ein binile-
# Anzahl der Achsen
# Technisch zulast ge Anhangelast gebremst in kg
# acheinigung Tall tayt älertor nicht erforderlicht.
# Technisch zislastige Anharigelast ungebremst in log
# VER
# (JECO
# ORUJOS
# +
# DATEM
# hubraum is of
# AuBerbetriebsetzung
# P.2/RA Nonnieistung In XWWenndrehzahl bel min
# Kraftstedfart eifer Esergiequelie
# I
# Leistungsgewicht in kwikg (nur bei Kraftrådum)
# Farbe des Fahrzeugs
# Sezpiazze einsetzwillich fennersitz
# Stadtverwaltung
# Hocasneschwindigkeit in km/h
# Staregorausch in de (A)
# A437457
# Kaiserslautern
# Zulassungsbehörde
# Drehzahl in ml:/ su UL1
# L. A.
# fahrgerausch in d9 (4)
# COy fin g/km) kombinierter trert
# F
# for die EG Typgenehmigung mailgobliche Schachtofticlasse
# Hersteller Kurzbezeichnung
# ZBI
# Code zu [2)
# 118978265
# Code 20 D.2 mit Profniffer
# Prutziffer zur Fahrzeug Identifizierungsnummer
# Azt des Aufbaus
# Franz Mustermann
# Musterweg 7
# 23456 Musterhausen
# Deutschland
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Musterhausen , 20. März 2013
# Versicherungsnummer: VN-6648000
# Ihr Schreiben vorn 20.10.2012
# Verehrte Damen und Herren,
# am 20.10.2012 teilten Sie mir mit, dass Sie die Kosten für eine ambulante
# psychotherapeutische Behandlung (50 Sitzungen a € 180,92) bei Herrn Dr. Gobbers
# erstatten.
# Nach eingehender Beratung, bin ich zu dem Entschluss gekommen, die Behandlung
# voraussichtlich nicht bei Herrn Dr. Gobbers durchzuführen, sondern bei Frau Dr.
# Wunder.
# Frau Wunder ist Gesundheitspraktikerin/DGAM (Deutsche Gesellschaft für alternative
# Medizin) und hat eine entsprechende psychotherapeutische Ausbildung.
# Ausbildungsnachweise können jederzeit nachgereicht werden.
# Die Kosten pro Sitzung betragen € 100,00. Ich bitte um Erstattung der Kosten für 50
# Sitzungen
# Mit den besten Empfehlungen
# F. Mustermann
# F. Mustermann
# Ayse Deli
# Am Schloß 9
# 35410 Hungen
# 22. Februar 2015
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Familienvielschutzversicherung 867800158
# Änderung der Bankverbindung
# Sehr geehrte Damen und Herren,
# meine Bankverbindung hat sich geändert. Bitte überweisen / belasten Sie künftig die Beträge auf
# mein neues Konto
# Kontonummer
# 90830810
# BLZ
# 25015088 bei der Beispielbank Musterhausen
# Vielen Dank.
# Freundliche Grüße
# Ayse Deli
# Sabine Kallmeyer, Im Bachgarten 60,50259 Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Pulheim, 11.09.2012
# Sehr geehrte Damen und Herren,
# hiermit möchten wir Ihnen eine Adressänderung mitteilen. Für alle unsere Versicherungen gilt die
# neue Adresse.
# Körnerstraße 7
# 52064 Aachen
# Mit freundlichen Grüßen
# S. Kallmeyer
# Krankenkasse bzw. Kostenträger
# Arbeitsunfähigkeits-
# 1
# TK - Techniker Krankenkasse
# bescheinigung
# Name, Vorname des Versicherten
# Siebel
# X
# Erstbescheinigung
# Ahmet
# geb, am
# 05.03.81
# Eiler Berg-Hang 251a
# Folgebescheinigung
# D 54619 Üttfeld
# Kostenträgerkennung
# Versicherten-Nr.
# 23025113
# LA894844280
# Arzt-Nr.
# Datum
# 281369213 |16.04.14
# Arbeitsunfall, Arbeitsunfall-
# dem Durchgangsarzt
# folgen, Berufskrankheit
# X
# zugewiesen
# arbeitsunfähig seit
# 21.06 15
# voraussichtlich arbeitsunfähig
# bis einschließlich oder letzter
# Tag der Arbeitsunfähigkeit
# festgestellt am
# 2| 02|19
# Vertragsarztstempel / Unterschrift des Arztes
# Ausfertigung zur Vorlage beim Arbeitgeber
# Muster 1b (1.2016)
# Nr.
# 51345
# ·
# www.praxisformulare.de
# ·
# Ohm
# Print
# Consulting
# GmbH
# ·
# Freisenbergstr.
# 21.58513
# Lüdenscheid
# TÜRKİYE CUMHURİYETİ KİMLİK KARTI
# REPUBLIC OF TURKEY IDENTITY CARD
# C
# 12345678902
# ACAR
# HAKAN
# 22.05.1975
# E/M
# S123456TC
# 7505297F
# TC/TUR
# 20.07.2017
# Zulassungsbescheinigung Teil I
# 20.01.2020
# 0005
# CTA005949
# 2 23
# 195/4000 230
# (Fahrzeugschein)
# 1
# M1G
# AC
# 4922-4922
# 2004-2004
# KL-S-0-086/20-00008
# WBACV610009B05052
# 2
# 1745-1745
# 2185-2185
# Europäische
# Bundesrepublik
# BMW
# -
# -
# Gemeinschaft
# D
# 140
# Deutschland
# G5X
# 211
# 2860
# 1.2
# 2860
# Canoeancregro sa perecopains - Vier 1 / Permiso de circulación, Parte 1 /
# Davidbeni e registraci - Cast | /Registreringsatrest. Del 1 /
# CV61
# 1320
# 2.2
# 1615
# -
# Mlpog1 / Registration certificate. Part I / Certificat d'immatriculation. Partie 1 /
# 1320
# Prometna dozvola Il / Carta di circolazione. Parte I / Registracijis apleciba.
# DAA509BA
# 8.2
# 1615
# -
# L daja / Registracijos Budlimit. I dalis / Forgalmi engedély. L. Rész / Certificat
# ta' Registrazioni, Lel Parti / Kentekenbewijs. Deel I / Dowod Rejestracyjny.
# 80
# 3000
# 69
# Capté 1 / Certificado de matricula, Parta 1 / Certificat de Inmatriculare Partei \ /
# Opveddenie o evidenci. Cast' I / Prometno dovoljenje. Del I A
# X5 xDrive30d
# 3500
# 750
# -
# A Arstliches Kennzeichen
# BAYER.MOT. WERKE-BMW
# 275/40 R21 107Y B
# KL W 892
# Geländefz.Pers.bef.
# 315/35 R21 111Y B
# C.1.1 Name oder Firmenname
# Kombilimousine
# INSIDERS Technologies
# 715/2007*2018/1832DG
# Schwarz
# GmbH
# EURO6; WLTP; DG; PI/CI; M, N1
# 9
# e1*2007/46*1918*06
# C.1.2 Vornamein)
# Diesel
# 22.08.2019
# FQ631379
# 0002 36DG
# 2993
# C.1.3 Anschrift
# Brüsseler Str. 1
# 22
# 7.2/8.2: +220 B. ANHÄNGEBETRIEB *WW.AHK LT.EGTG *FZ IST
# 67657 Kaiserslautern
# BEI WERKSSEITIG MONTIERT. AHK M. SPEZ. FAHRDYN. STABI . SY
# ST. F.ANH.BETR.F. TEMPO 100 KM/H GEM. 5.AND. VO Z. 9. AUSN
# . VO. Z. STVO AUSGESTATTET +
# X Nachite HU
# [Monat und Jahrte
# Kaiserslautern
# 1
# CAc Der With
# 01/2023 ! Butune
# obescheinigung wird nicht 26. 03.2020
# Fahrzeugs ausgewiesen.
# Riadh Schweitzer
# Detmolder Str. 2-4
# 51109 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Kündigung
# 27.08.2013
# Verehrte Damen und Herren,
# leider muss ich Ihnen mitteilen, dass meine Eltern Liese
# und Robert am 10.08.2013 ums Leben gekommen sind.
# Somit möchte ich deren Rentenversicherung mit der Nummer
# Z-99986 mit sofortiger Wirkung kündigen. Bitte geben Sie
# mir Bescheid, sollten Sie noch nachweisende Unterlagen
# benötigen. Ich bitte Sie außerdem um eine schriftliche
# Bestätigung der Kündigung.
# Freundliche Grüße
# Schweiker
# Krankenkasse bzw. Kostenträger
# Arbeitsunfähigkeits-
# 1
# Daimler BKK
# bescheinigung
# Name, Vorname des Versicherten
# Vetter
# X
# 20.0 geb.@n]
# Erstbescheinigung
# Roman
# Waldhofweg 157
# Folgebescheinigung
# 96052 Bamberg
# Kostenträgerkennung
# Versicherten-Nr.
# 516601729
# I985323600
# Arzt-Nr.
# Datum
# 296640963 10.01.14
# Arbeitsunfall, Arbeitsunfall-
# folgen, Berufskrankheit
# dem Durchgangsarzt
# zugewiesen
# arbeitsunfähig seit
# 18.06.19
# voraussichtlich arbeitsunfähig
# bis einschließlich oder letzter
# 14.09.|19
# e.de
# .
# Ohm
# Print
# Consulting
# GmbH
# .
# Frelsenbergstr.
# 21.58513
# Lüdenscheid
# Tag der Arbeitsunfähigkeit
# festgestellt am
# 26.07. 17
# Ausfertigung zur Vorlage beim Arbeitgeber
# Vertragsarztstempel / Unterschrift des Arz
# Muster 1b (
# Manfred Meier, Hauptstraße 200,39524 Fischbeck
# Lebensgut Versicherungsgesellschaft
# Brüsseler Straße 1
# 67657 Kaiserslautern
# Mannheim, den 21.06.2013
# Betreff: Meldung Hochwasserschaden; Versicherungs-Nr. 030/98/24061990
# Sehr geehrte Damen und Herren,
# wie Sie sicherlich in den Medien verfolgt haben, ist durch das Elb-Hochwasser Anfang Juni nahe
# meines Wohnortes Fischbeck der Hauptdeich der Elbe gebrochen, wodurch Fischbeck innerhalb
# weniger Stunden komplett überflutet wurde. Dieser Deichbruch kam für mich völlig unerwartet und
# auch die örtlichen Behörden hatten keinerlei Warnungen vor der Möglichkeit eines solchen
# Ereignisses ausgesprochen. Ich hatte daher keinerlei Möglichkeit mich auf die Überflutung
# vorzubereiten und bewegliche Gegenstände entsprechend vor dem Eintreffen der Wassermassen zu
# entfernen, so dass auf meinem Grundstück die folgenden Schäden entstanden sind:
# .
# Wasserschaden am Gebäude; Schätzung laut Gutachter: 75.000 €
# .
# Totalschaden KFZ BMW 320d Baujahr 2003; Wert laut Schwacke-Liste: 11.600 €
# Fast vollständige Zerstörung meines Gartens; geschätzter Schaden: 15.000 €
# Vollständige Zerstörung meiner Gartenmöbel, bestehend aus folgenden Einzelpositionen
# o Tisch; Neupreis 599 ,- €
# O
# Sitzbank; Neupreis 489 ,- €
# 0
# 4 Stühle; Neupreis 699 ,- €
# Sonnenschirm; Neupreis 199 ,- €
# 0
# 0
# Kugelgrill; Neupreis 149 ,- €
# Ich bitte Sie mir mitzuteilen, inwieweit Sie diese Schäden im Rahmen meiner Hausratversicherung
# (Versicherungs-Nr. 030/98/24061990) begleichen werden. Die Belege würde ich dann entsprechend
# nachreichen. Ich hatte bereits versucht diese Information von Ihnen telefonisch zu erhalten,
# allerdings hat der Sachbearbeiter darauf bestanden, dass ich Ihnen hierzu einen formalen Brief
# schreiben muss. Ich finde ein derartig bürokratisches Vorgehen in der aktuellen Situation, in der die
# vom Hochwasser betroffenen Familien schon genug um die Ohren haben, absolut inakzeptabel und
# hoffe nun zumindest auf eine kulante Schadensabwicklung ihrerseits.
# Mit freundlichen Grüßen
# Manfred Meier
# Absender:euroShell Cards B.V.
# Rechnung
# euroShell
# P.O. Box 27
# Card
# 3000 AA Rotterdam
# The Netherlands
# Seite 1/2
# Rechnung v.: EUROSHELL DTL. GMBH & CO.KG
# Kunde:
# Rückfragen richten Sie bitte an: 040-809080500
# Rechnungsnummer:
# S21301265
# INSIDERS TECHNOLOGIES GMBH
# Customer Service Center
# Referenz:
# TOUCHLESS_FLEET
# BRUESSELER STRASSE 1
# Suhrenkamp 71 - 77
# Buchungskonto-Nr:
# 11315392
# 22335 Hamburg
# Rechnungsdatum:
# 31-05-2013
# Währung:
# EUR
# 67657 KAISERSLAUTERN
# Steuernummer Kunde:
# DE223304264
# GERMANY
# Internet: www.euroshell.de
# *Festnetz: € 0,14/Min
# e-mail:card-kundenservice-de@shell.com Mobilfunk: max. € 0,42/Min.
# Diese Rechnung wurde erstellt am:01-06-2013
# Rg-Betrag gesamt: 1383,35 EUR
# Fällig am: 11-06-2013
# Zusammenfassung der berechneten Lieferungen/Leistungen
# Produkt
# Menge Einheit
# MwSt. %
# Betrag ex. MwSt.
# MwSt. - Betrag
# Betrag
# inkl. MwSt.
# Lieferungen Mai 2013
# OK Super E10
# 024
# 120,49 Liter
# 19,00%
# 154,82
# 29,41
# 184,23
# Diesel
# 032
# 808,18 Liter
# 19,00%
# 964,55
# 183,25
# 1147,80
# Gesamt Kraftstoffe
# 928,67
# Liter
# 1119,37
# 212,66
# 1332,03
# Zubehör
# 053
# 19,00%
# 3,74
# 0,71
# 4,45
# Autowäsche
# 065
# 19,00%
# 22,56
# 4,29
# 26,85
# Nicht Krafstoffe gesamt
# 26,30
# 5,00
# 31,30
# Kartengebühren
# 007
# 19,00%
# 16,80
# 3,22
# 20,02
# Gebühren gesamt
# 16,80
# 3,22
# 20,02
# Gesamt Rechnungsbetrag
# 1162,47
# 220,88
# 1383,35
# Gesamt Rechnungsbetrag
# 1162,47
# 220,88
# 1383,35
# Berechnete Mengen und Anzahl der Leistungen gemäß Lieferschein
# Steuernummer: DE 815303 369, euroShell Deutschland Gmbh & Co. KG, Postfach 600 444,/22204 Hamburg
# Handelsregister-Nr. HRA 113721 ; Geschäftsführung: Grischa Sauerberg, Andreas Grobler, Marc-Oliver Ziegenbein.
# Invoices are processed and produced centrally by euroShell Cards B. V. for its customers in Europe
# Krankenkasse bzw. Kostenträger
# 1
# K
# Arbeitsunfähigkeits-
# bescheinigung
# Name, Vorname des Versicherten
# Emin
# Erstbescheinigung
# Struwwelpeterplatz 138
# 2 geb. am
# $11.91
# D 20255 Hamburg
# Folgebescheinigung
# Kostenträgerkennung
# 4889967
# Versicherten-Nr.
# V044778757
# Arzt-Nr.
# 289581364 24.12.10
# Datum
# Arbeitsunfall, Arbeitsunfall-
# dem Durchgangsarzt
# folgen, Berufskrankheit
# zugewiesen
# arbeitsunfähig seit
# /02/02/19
# voraussichtlich arbeitsunfähig
# 01/16
# bis einschließlich oder letzter
# Tag der Arbeitsunfähigkeit
# festgestellt am
# 04.10 17
# Vertragsarztstempel / Unterschrift des Arztes
# Ausfertigung zur Vorlage beim Arbeitgeber
# Muster 1b (1.2016)
# Nr.
# 51345
# ·
# www.praxisformulare.de
# ·
# Ohm
# Print
# Consulting
# GmbH
# ·
# Freisenbergstr.
# 21
# -
# 58513
# Lüdenscheid
# Marianne Rosenberg
# Kaiserstraße 60
# 55116 Mainz
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Mittwoch, 18.05.2010
# Betr .: Versicherungsnr. 3210314
# Hallo zusammen,
# hiermit kündige ich o.g. Versicherung aus finanziellen Gründen zum nächsten Monatsende dieses
# Jahres.
# Bitte bestätigen Sie mir diesen Vorgang.
# Viele Grüße
# Marianne Rosenberg
# £
# Christian Beck, Vogelsanger Weg 119,50858 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 27.08.2013
# Widerruf zu Versicherung NR 5555574:
# Sehr geehrte Damen und Herren,
# die Police für die im Betreff genannte Unfallversicherung haben Sie mir nun erstmals zugesandt. Nach
# Überprüfung teile ich Ihnen hiermit mit, dass ich von meinem Widerrufsrecht Gebrauch mache. Die
# Unfallversicherung ist somit nicht zustande gekommen.
# Die bisher durch Sie eingezogenen Beiträge wollen Sie bitte umgehend auf mein Girokonto, welches Ihnen
# bekannt ist, zurück überweisen.
# Mit freundlichen Grüßen
# C. M. Beck
# Europäische Gemeinschaft
# Bundesrepublik Deutschland
# D)
# Zulassungsbescheinigung Teil II
# (Fahrzeugbrief)
# CBNAETenCTBOTO 3a perncTpauna - yaCT Il / Permiso de circulación. Parte II / Osvědčení o registraci - Část Il / Registreringsattest. Del II / Registreerimistunnistus. Osa Il /
# AÔEla KUKAomopla/ILtonikó Es. Mepo II / Registration certificate. Part II / Certificat d'immatriculation. Partie Il / Prometna dozvola Il / Carta di circolazione. Parte Il /
# Registracijas aplieciba. Il. dala / Registracijos liudijimas. Il dalis / Forgalmi engedély. Il. Rész / Certifikat ta' Registrazzjoni. It-Il Parti / Kentekenbewijs. Deel Il /
# Dowód Rejestracyjny. Część II / Certificado de matrícula. Parte II / Certificat de înmatriculare Partea II / Osvedčenie o evidencii. Čast' Il / Prometno dovoljenje. Del II /
# Rekisteröintitodistus. Osa Il / Registreringsbeviset. Del II
# Diese Bescheinigung nicht im Fahrzeug aufbewahren!
# A
# Amtliches Kennzeichen
# B
# Datum der Erstzulassung
# 22.11.2019
# (1)
# Anzahl der Vorhalter
# 0
# (1)
# Anzahl der Vorhalter
# des Fahrzeugs
# C.3.
# Name oder Firmenname
# C.6.1
# C.3.2
# Vorname(n)
# C.6.2
# C.3.3
# Anschrift zum Zeitpunkt
# der Ausstellung der
# C.6.3
# Bescheinigung
# C.4c
# Der Inhaber der Zulassungsbescheinigung wird nicht als Eigentümer des Fahrzeugs ausgewiesen.
# -
# -
# Datum
# 22.11.2019
# Datum
# Stadt Essen
# S
# N.Der Oberbürgermeister
# SCOUS
# BISCHER
# 15
# 3003.40
# cv4tamRk09
# Nur zur Nutzung des Sicherheitscodes
# im internetbasierten Zulassungsver-
# FN 465862
# fahren freilegen. Dokument nur
# unbeschädigt gültig.
# (Nummer der Zulassungsbescheinigung)
# (Fahrzeug-Identifizierungsnummer als Barcode)
# 0.1
# Marke
# VOLKSWAGEN, VW
# (23) Raum für interne Vermerke des Herstellers
# Typ
# AW
# 2020000212 AW14NZ DEU390 COC JA
# D.2
# Variante
# ABDPCA
# Version
# FD7FD7CWO02N2VR24BF1CAO
# 23074254
# HRQ634 31968 AL 132
# D.3
# Handelsbezeichnung(en)
# POLO
# (2)
# Hersteller-Kurzbezeichnung
# VOLKSWAGEN - VW
# 183
# (2.1)
# Code zu (2)
# 0603
# (2.2)
# Code zu D.2 mit
# CIF000178
# Prüfziffer
# E
# Fahrzeug-Identifizierungs-
# WVWZZZAWZLY023008
# 3)
# Prüfziffer zur Fahrzeug-
# 4
# nummer
# Identifizierungsnr.
# J
# Fahrzeugklasse
# M 1
# Art des
# (4) Afhaus
# AB
# (24) Diese Bescheinigung wurde für das nebenstehend beschriebene Fahr-
# 5)
# Bezeichnung der Fahrzeug-
# Fz. z. Pers.bef.b. 8 Spl.
# zeug ausgegeben durch (Zulassungsbehörde bzw. Genehmigungsinhaber):
# klasse und des Aufbaus
# Schräghecklimousine
# VOLKSWAGEN AG
# WEISS
# (11) 2R
# ppa.
# O
# R
# Farbe des Fahrzeugs
# P. 1
# Hubraum in cm3
# 1498
# 24.09.2019
# P.2
# Nennleistung in kW
# P.4
# Nenndrehzahl bei min-1
# 110
# /5000
# P.3
# Kraftstoffart oder
# Energiequelle
# Benzin
# 10) Code 000 1
# Datum:
# K
# Nummer der EG-Typ-
# e 1 2007 / 46*1783*16
# Datum
# 30.08.2019
# Unterschrift:
# genehmigung oder ABE
# (6)
# zu K
# 17
# Merkmal zur Betriebs-
# erlaubnis
# 25)
# Zusätzliche Vermerke der Zulassungsbehörde:
# (maschinenlesbare Nummer der Zulassungsbescheinigung)
# -BUNDES
# /
# DRUCKEREI
# 2017
# Insiders
# Versicherungen
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Marianne Rosenberg
# Kaiserstraße 60
# 55116 Mainz
# Ort: Kaiserslautern, Datum: 31.10.2013
# Heil-und Kostenplan Dr. Köhler vom 10.10.2013
# Sehr geehrte Frau Rosenberg,
# wir erstatten die Kosten der geplanten Zahnersatzmaßnahme im tariflichen Rahmen. Grundlage für
# die Berechnung unserer Erstattungsleistung ist der vorgelegte Heil- und Kostenplan. Danach erhalten
# Sie insgesamt 3.260,75 €.
# Wir errechneten den Betrag aus:
# Tarif A05 Leistung 2.600 ,-- €
# Tarif 75 Leistung 660,75 €
# Im Tarif A05 können pro Person maximal Aufwendungen bis zu 2.600 ,-- € jährlich berücksichtigt
# werden. Die erstattungsfähigen Aufwendungen werden, soweit sie 2.600 ,-- € übersteigen, nach Tarif
# 75 mit 75% vergütet. Unsere Erstattungszusage vermindert sich um den vertraglich vereinbarten
# Selbstbehalt (1.000 ,-- €) aus Tarif A05, soweit er für das Kalenderjahr zu berücksichtigen ist. Noch
# eine Bitte! Senden Sie uns auch die spezifizierte Material- und Laborrechnung. Wir wünschen einen
# guten Behandlungserfolg. Die Zahnarztrechnung von 851,79 € geben wir Ihnen zurück, da der o. g.
# Selbstbehalt nicht erreicht ist. Sollten weitere Rechnungen für das Behandlungsjahr anfallen, bitten
# wir um Vorlage aller Rechnungen.
# mit freundlichen Grüßen
# Janina Huth
# Ihre Insiders Versicherungen
# Zulassungsbescheinigung Teil I
# 1 230
# (Fahrzeugschein)
# 15.07.20201
# 00052
# CZD000037
# 2.
# 1 PZ
# 140/4000
# KL-S-0-197/20-00033
# MI
# P.4
# AC
# 4709-4709
# 1827-1827
# WBA11DZ010FK03792
# 1705-1705
# Europaische
# Gemeinschaft
# D
# Bundesrepublik
# BMW
# 1440-1440
# Deutschland
# 15
# Cuocerenordicro za perrosum Har ( / Permiso de circulación. Parto /
# G3K
# 2225
# 2225
# Osvědčení o registraci - Cast | /Registreringsattest. Dell /
# mistunnistus. Osa T/ Ačova
# 11DZ
# 136
# Registration certificate.
# Certificat d'immatriculation. Partie 1/
# 1290
# PoMem dovole ) / Carta di circolazione. Parte )/ Registracijas apleciba.
# Part I
# IAW500BO
# 1025
# Recstracgos Iukiyiries. Iaalls / Forgarni engedély. I. Resz / Certifikat
# 1025
# 1290
# 63
# strazzioni. be Part / Kentekenbewijs. Deel I / Dowód Rejestracyjny.
# Castel
# Certficado, de matricula. Parte | / Certificat de Inmatriculare Partua 1 /
# -
# 6
# 320d
# 12
# 3000
# ecceras o evidencit Cast | / Promethe dovoljenje, Dell /
# U2
# Rekisterdigatodistus. Osat / Registreringsbeviset. Det
# 0.3
# &'Amulches Karnaaichen..
# KL A 2347
# BAYER.MOT. WERKE-BMW
# 1800 02
# 750
# Fz. z. Pers. bef.b. 8 Spl.
# 225/45 R18 95Y B
# lama oder Für
# 225/45 R18 95Y B
# iname
# Insiders Technologies
# Kombilimousine
# -
# 715/2007*2018/1832AP
# GmbH
# EURO6; WLTP;AP/PI/CI; M, NI
# Blau
# 11
# C.1.2 Vornamein)
# Hybr. Diese1/E
# e1*2007/46*2017*02
# 0010
# 05.02.2020
# 7.2/8.2: +120 B.ANHANGEBETRIEB *WW. AHR LT. EGTG #ZU P2/
# 36AP
# 1995
# FU304524
# C.1.3 Amsc
# Brüsseler Str. 1
# P4: ENTFÄLLTKW/30MIN; NENNLEISTUNG 2.2KW *
# 67657 Kaiserslautern
# X
# Nächste Huf
# (Monat und Jahr).
# Kaiserslautern
# 07/2023
# 1 Daturn:
# 15.07.2020
# C.d.c. Der Inhaber der Zulassungsbescheinigung wird nicht als Eigentümer des
# Fahrzeugs ausgewiesen.
# Franz Mustermann
# Musterweg 7
# 23456 Musterhausen
# Deutschland
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 27.08.2013
# Widerspruch zum Versicherungsvertrag
# Verehrte Damen und Herren,
# bzgl. o.g. Versicherung bei der Insiders Versicherung, welche Sie ohne mein
# Wissen und ohne meine Zustimmung für mich abgeschlossen haben, habe
# ich ihnen zum Monatsanfang eine E-Mail geschickt in der ich diesem
# Vertrag, für den ich weder eine Vertragspolice erhalten, noch eine
# Unterschrift
# ausdrücklich geleistet habe, widerspreche und Sie darum bitte, sich um die
# Angelegenheit zu kümmern und sich bei mir zu melden.
# Diese E-Mail haben Sie nachweislich am 05.08.2013 abgerufen.
# Nachweislich, weil ich die Mail als Einschreiben verschickt habe und von
# meinem Provider einen Beleg dafür erhalte habe.
# Als ich gestern bei der Insiders Versicherung angerufen habe um nach dem
# Bearbeitungsstand zu fragen, nachdem ich jetzt eine Folgebeitragsrechnung
# erhalten habe, wurde mir mitgeteilt, das Sie sich bisher nicht mit der alten
# Versicherung in Verbindung gesetzt hätten und das gegen mich bestehende
# Mahnverfahren an das Gericht weitergegeben wird.
# Ich fordere Sie hiermit erneut auf sich unverzüglich um die Angelegenheit
# zu kümmern und mir Bescheid (möglich schriftlich per E-Mail) zu geben.
# Zulassungsbescheinigung Teil I
# (Fahrzeugschein)
# 15.07.2020. 0005 CZD000037
# 2.
# I Pz
# 14074000 T
# 230
# KL-S-0-197/20-00033
# MI
# P.4
# AC
# 4709-4709
# 1827-1827
# WBAIIDZ010FK03792
# 2
# 1440-1440
# 1705-1705
# Europäische
# Gemeinschaft
# D
# Bundesrepublik
# Deutschland
# BMW
# 75
# Carcerenordicro za pervyroque Hanr ( / Permiso de circulación. Parte \ /
# G3K
# 12
# -
# 136
# 2225
# Osvědčení o registraci - Část | /Registreringsattest. Dell /
# 2225
# IF.2
# treeni
# Miboct/ Registration certificate. Part T/ Certificat d'immatriculation. Partie 1/
# 11DZ
# V.
# 7
# Prometma Carvole | / Carta di circolazione. Parte 1/ Registracijas apliecibo.
# D.2
# IAW500BO
# 1025
# 1290
# 73
# k (aa / Registracgos lukijires. Idalls / Forgalmi engedély. I. Rész / Certifikat
# 71
# 1025
# 1290
# Recitazzioni. b- Farti / Kentekenbewijs, Deel ! / Dowód Rejestracyjny.
# 16.1
# 8.3
# Cestél / Certificado, de matrícula. Parte | / Certificat de Inmatriculare Partua 1 /
# -
# 12
# u.2
# 3000
# 67
# Osvedcenae o evidencit, Cast | / Promethe dovoljenje, Dell /
# Rekisterdigatodistus. Osat / Registreringsbeviset. Dell
# 320d
# UM
# 10.3
# DE
# A Amulches Karczaichen..
# BAYER. MOT. WERKE-BMW
# 1800
# 02
# 750
# 01
# 5.1
# 0 52
# KL A 2347
# Fz. z. Pers.bef.b. 8 Spl.
# 225/45 R18 95Y B
# 15.1
# C.1.1 Name oder Firmenname
# 225/45 R18 95Y B
# Insiders Technologies
# Kombilimousine
# 715/2007*2018/1832AP
# -
# GmbH
# EURO6; WLTP; AP PI/CI¡ M, N1
# Blau
# el*2007/46*2017*02
# 5
# mein
# Hybr. Diese1/E
# 0010 | 36AP
# 05.02.2020
# 1995
# FU304524
# C1.3 Am
# -
# Brüsseler Str. 1
# 7.278.2: +120 B. ANHÄNGEBETRIEB *WW. AHK LT. EGTG *ZU P2/
# P4: ENTFÄLLTKW/30MIN; NENNLEISTUNG 2.2KW *
# 67657 Kaiserslautern
# X Nächste KU
# (Monat und Jahre
# Kaiserslautern
# 07/2023
# 1. Daturn:
# 15.07.2020
# C.c. Der Inhaber der Zulassungsbescheinigung wird nicht als Eigentümer des
# Fahrzeugs ausgewiesen.
# Herr Schmidt
# Baumwall 56
# 20459 Hamburg
# An
# Lebensgut Versicherungsgesellschaft
# Abtl. Kraftschaden / Personenschaden
# Brüsseler Straße 1
# 67657 Kaiserslautern
# Betr .: Schaden Nr.: 184-JS-07-123456-0; Ihre Zahlung von 315 Euro
# Sehr geehrte Damen und Herren,
# mit Verwunderung habe ich Ihre Überweisung erhalten. Ich gehe schwer
# davon aus, dass dieser Betrag nur eine ANZAHLUNG war !!!
# Ich fordere Minimum 15.000 € - ohne die Anzahlung. Diese überweisen Sie
# bitte an das folgende Konto:
# Kristian Schmidt
# Apfelsinen Bank
# Kto: 5555999
# BLZ: 78945623
# Sie haben dafür bis zum 30.02.2010 Zeit.
# Sollte nach Ablauf dieser Frist noch immer kein Zahlungseingang ersichtlich
# sein, werde ich einen Rechtsanwalt einschalten, der die Zahlungen für Sie
# NOCH TEURER macht!
# Ich befinde mich immer noch in therapeutischer Behandlung und kann
# meinem Beruf nicht nachgehen!
# Mit freundlichen Grüßen,
# (Kristian Schmidt)
# Hamburg, 3.02.2010
# Laurent Bucher
# Konstanty-Gutschow-Str. 8
# 30625 Hannover
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 30. Jan. 2013, Hannover
# Betr. Automatische Erhöhung der Zuwachsversicherung 5547810
# Bezug: Ihr Schreiben vom 02.01.2013
# Guten Tag,
# hiermit widerspreche ich der automatischen Erhöhung der Versicherung. Bitte
# berücksichtigen Sie dies bei Ihrem Beitragseinzug.
# Freundliche Grüße
# Boucher
# Krankenkasse bzw. Kostenträger Direkte der AOK Hel Arbeitsunfähigkeits-
# 1
# bescheinigung
# Name, Vorname des Versicherten
# Alice
# Hippergrund 261
# 25 gel. am. 50
# Erstbescheinigung
# D 16259 Hohenwutzen
# Folgebescheinigung
# Kostenträgerkennung 5 Versicherten-N9 70087
# 2227464716 05. 03.14
# Arbeitsunfall, Arbeitsunfall-
# dem Durchgangsarzt
# folgen, Berufskrankheit
# zugewiesen
# 20.10,19
# arbeitsunfähig seit
# 01.07.16
# voraussichtlich arbeitsunfähig
# bis einschließlich oder letzter
# Tag der Arbeitsunfähigkeit
# 05.05,16
# festgestellt am
# Vertragsarztstempel / Unterschrift des Arztes
# Muster 1b (1.2016)
# Ausfertigung zur Vorlage beim Arbeitgeber
# Nr.
# 51345
# ·
# www.praxisformulare.de
# ·
# Ohm
# Print
# Consulting
# GmbH
# ·
# Freisenbergstr.
# 21.58513
# Lüdenscheid
# Europäische Gemeinschaft
# Bundesrepublik Deutschland
# D)
# Zulassungsbescheinigung Teil II
# (Fahrzeugbrief)
# CBNAETENCTBOTO 3a perucTpauna - YacT Il / Permiso de circulación. Parte II / Osvědčení o registraci - Část Il / Registreringsattest. Del II / Registreerimistunnistus. Osa Il /
# Adela KUKAomoplag/Tiotonik E. Mo II / Registration certificate. Part II / Certificat d'immatriculation. Partie Il / Prometna dozvola Il / Carta di circolazione. Parte II /
# Registracijas aplieciba. Il. dala / Registracijos liudijimas. Il dalis / Forgalmi engedély. Il. Rész / Certifikat ta' Registrazzjoni. It-Il Parti / Kentekenbewijs. Deel Il /
# Dowód Rejestracyjny. Część II / Certificado de matrícula. Parte II / Certificat de înmatriculare Partea Il / Osvedčenie o evidencii. Čast' Il / Prometno dovoljenje. Del II /
# Rekisteröintitodistus. Osa Il / Registreringsbeviset. Del Il
# Diese Bescheinigung nicht im Fahrzeug aufbewahren!
# A
# Amtliches Kennzeichen
# B
# Datum der Erstzulassung
# 27.11.2019
# (1) |Anzahl der Vorhalter
# des Fahrzeugs
# 0
# (1)
# Anzahl der Vorhalter
# C.3.
# C.6.1
# Name oder Firmenname
# C.3.2
# Vorname(n)
# C.6.2
# C.3.3
# Anschrift zum Zeitpunkt
# der Ausstellung der
# C.6.3
# Bescheinigung
# C.4c
# Der Inhaber der Zulassungsbescheinigung wird nicht als Eigentümer des Fahrzeugs ausgewiesen.
# Datum
# 27.11.2019
# Datum
# Stadt Essen
# TESS
# ``Der Oberbürgermeister
# i.A.
# CUIUTY
# CO
# 25ACC
# DDa5AeC3y0
# Nur zur Nutzung des Sicherheitscodes
# im internetbasierten Zulassungsver-
# FN628566
# fahren freilegen. Dokument nur
# unbeschädigt gültig.
# (Nummer der Zulassungsbescheinigung)
# (Fahrzeug-Identifizierungsnummer als Barcode)
# D.1
# Marke
# VOLKSWAGEN, VW
# (23) Raum für interne Vermerke des Herstellers
# Typ
# 5N
# D.2
# ACDPCAXO
# 2020000382 AD14BZ DEU390 COC JA
# Variante
# Version
# FD7FD7GC008N5N1TVR24BF1CSA
# 23237968
# HXZ665
# 31968 AL 132
# D.3
# Handelsbezeichnung(en)
# TIGUAN
# (2)
# Hersteller-Kurzbezeichnung
# VOLKSWAGEN - VW
# 183
# (2.1)
# Code zu (2)
# 0603
# (2.2)
# Code zu D.2 mit
# CIR024662
# Prüfziffer
# E
# Fahrzeug-Identifizierungs-
# WVGZZZ5NZLW333697
# (3)
# Prüfziffer zur Fahrzeug-
# 4
# nummer
# Identifizierungsnr.
# Fahrzeugklasse
# M 1
# (4)
# Art des
# AC
# Aufbaus
# (5
# Bezeichnung der Fahrzeug-
# Fz . z. Pers.bef.b. 8 Spl.
# (24) Diese Bescheinigung wurde für das nebenstehend beschriebene Fahr-
# zeug ausgegeben durch (Zulassungsbehörde bzw. Genehmigungsinhaber):
# klasse und des Aufbaus
# Kombilimousine
# R
# Farbe des Fahrzeugs
# GRAU
# (11) Code
# 7
# VOLKSWAGEN AG
# ppa.
# 1498
# P.2
# Nennleistung in kW
# 110
# /5000
# 21.11.2019
# P.1
# Hubraum in cm3
# P.4
# Nenndrehzahl bei min"1
# P.3
# Kraftstoffart oder
# Energiequelle
# Benzin
# (10) ZU P.3
# 0001
# Datum:
# K
# Nummer der EG-Typ-
# genehmigung oder ABE
# e1/2001 / 116*0450 *45
# (6)
# Datum
# 02.09.2019
# Unterschrift:
# Zu K
# 17
# Merkmal zur Betriebs-
# erlaubnis
# 25)
# Zusätzliche Vermerke der Zulassungsbehörde:
# (maschinenlesbare Nummer der Zulassungsbescheinigung)
# BUNDES
# &#
# DRUCKEREI
# 2017
# Ayse Deli
# Am Schloß 9
# 35410 Hungen
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Montag, den 16.12.2014
# Antrag auf Beitragsfreistellung
# für VNR 998445
# Verehrte Damen und Herren,
# ich bitte Sie o.g. Lebensversicherung bis auf weiteres beitragsfrei zu stellen.
# Mit den besten Empfehlungen
# A. Deli
# €€€
# Investment
# Einzugsermächtigung Ich ermächtige Insiders widerrufich, meine regelmäßigen Zahlungen mittels Lastschrift einzuziehen. Der Einzug sell as rechtzeitig erfolgan, daß der Kauf zu den gewünschten Temle möglich ist.
# Vor- und Zuname
# Kontonummer
# BLZ
# Abweichende Bankverbindungen für Folgeaufträge geben Sie
# Kreditinstitut/Ort
# bitte jeweils gesondert bekannt.
# -
# -
# Feststellung des wirtschaftlich Berechtigten:
# für eigene Rechnung
# für Rechnung von
# Vor- und Zuname
# Straße und Haus-Nr.
# and
# PLZ
# Ort
# -
# Besondere Bedingungen für den Altersvorsorge-Sparplan nach § 37 m Gesetz über Kapitalanlagegesellschaften (KAGG)
# -
# Zwischen dem Anleger und Insiders wird hiermit ein Altersvorsorge-Sparplan nach § 37 m KAGG vereinbart
# 1. Für Altersvorsorge-Sparpläne gelten in Abweichung und Ergänzung zu den Bedingungen für G-AS-Depots (Geschäftsbedingungen) diese Besonderen Bedingungen.
# 2. Der Anleger ist verpflichtet, entsprechend den getroffenen Vereinbarungen, während der Vertragslaufzeit regelmäßige Einzahlungen vorzunehmen. Die Möglichkeit zur jederzeitigen
# Rückgabe der Anteile bleibt unberührt.
# 3. Abweichend von Nr. 10 der Geschäftsbedingungen kann der Anlager den Altersvorsorge-Sparplan unter Einhaltung einer Kündigungsfrist von drei Monaten zum Ende eines
# Kalendervierteljahres kündigen. Die Kündigungsfrist beträgt vier Wochen zum Ende eines Kalendermonats, wenn der Anleger nach Vertragsabschluß arbeitslos oder völlig erwerb-
# sunfähig geworden ist.
# 4. Abweichend von Nr. 11 der Geschäftsbedingungen kann Insiders den Altersvorsorge-Sparplan nur aus wichtigem Grund kündigen. Als wichtiger Grund für eine Kündigung gilt nicht,
# wann der Anleger aufgrund einer nach Vertragsabschluß eingetretenen Arbeitslosigkeit oder Erwerbsunfähigkeit seine Verpflichtung zu regelmäßigen Einzahlungen nicht oder nur
# unvollständig erfüllt.
# 5. Der Anlager kann den Umtausch der erworbenen Antsile an Altersvorsorge-Sondervendigen gegen Anteile eines anderen von Insiders Inwww.verwalteten Fonds seiner Wahl ohne
# Berechnung eines Ausgabeaufschlages oder sonstiger Umtauschkosten verlangen.Insiders Investkann den kostenlosen Umtausch verwaigem, we.an im Zeitpunkt des
# Umtauschverlangens noch nicht 3/4 der vereinbarten Vertragslaufzeit abgelaufen sind.
# 8. Insiders bietet dem Anleger nach Ablauf der vereinbarten Vertragslaufzeit den Abschluß sines Auszahiplans an, so daß der Anleger nach Beendigung des Altersvorsorge-Sperplans
# ...
# Geburtsdatum
# Insiders GmbH
# Ergänzung/Geburtsname
# Ist der Antragsteller minderjährig, muß der
# Antrag von den gesetzlichen Vertretern (in
# der Regel beide Elternteile) unterschrieben
# Straße und Haus-Nr.
# werden. Die Eltern bevollmächtigen sich
# Brüsseler Straße 1
# gegenseitig, als gesetzliche Vertreter des
# Minderjährigen den Depotinhaber allein zu
# vertreten.
# Land
# PLZ
# 67657
# Kaiserslautern
# Nationalität
# Beruf
# selbst.
# angest
# Steuerausländer
# Bei vom Wohnsitz abweichender Versandanschrift bitte separates Blatt beifügen.
# Gesetzliche/r Vertreter
# Herr
# Frau
# Vor- und Zuname/Geburtsname des 1. gesetzlichen Vertreters (Mutter oder Vater)
# Geburtsdatum
# Vor- und Zuname/Geburtsname des 2. gesetzlichen Vertreters (Mutter oder Vater)
# Geb.- Datum 2. gesetzl. Vertr.
# Nationalität
# Beruf
# | selbst.
# angest.
# Steuerausländer
# ..
# Vollmacht für den Todesfall
# Keine Erbregelung; nach meinem Ableben ist folgende Person bevollmächtigt, über dieses Depot zu verfügen:
# Vor- und Zuname
# Geburtsdatum
# Ergänzung/Geburtsname
# Straße und Haus-Nr.
# Land
# PLZ
# Ort
# Anlageauftrag
# Die Anlage soll in folgendem Sondervermögen erfolgen:
# [X] GenoAS: 1
# Ausgabeaufschlag: 3 % des Anteilwertes
# Verwaltungsvergütung: (max.) 1,5 % p. a. des börsentäglich festgestellten Inventarwertes, derzeit 0,8 % p. a.
# Altersvorsorge-Sparplan
# Laufzeit des Anlageauftrages
# Jahre (mind. 18 Jahre) oder
# bis zur Vollendung des
# Lebensjahres (mind. 60. Lebensjahr)
# Anlageplan:
# Ich wünsche eine regelmäßige Anlage des folgenden Geldbetrags
# EUR
# mind. EUR 50 ;-,
# erster Kauf zum
# monat.
# 2monatl.
# X jährl.
# [1% jährl.
# jährlich
# letzter Kauf zum
# X] einmaliger Anlageauftrag
# ] zusätzlicher Anlageauftrag zum Altersvorsorge-Sparplan
# Ich ermächtige Insiders Investment den Betrag in Höhe von EUR
# 10.000
# sofort (bei Antragseingang) einzuziehen.
# Bitte Feld „Einzugsermächtigung“ ausfüllen.
# 50/1/1/260
# Krankenkasse bzw. Kostenträger
# Arbeitsunfähigkeits-
# 1
# BKK Voralb HELLER*INDEX*LEUZE
# bescheinigung
# Name, Vorname des Versicherten
# Durmus
# 14.0 @eb. 6ml
# Erstbescheinigung
# Leano
# Degenweg 3.2
# X
# Folgebescheinigung
# D 99102 Haarbergb Erfurt
# Kostenträgerkennung
# Versicherten-Nr.
# 387557341
# N324729358
# Arzt-Nr.
# Datum
# 662754936 11.04.10
# Arbeitsunfall, Arbeitsunfall-
# folgen, Berufskrankheit
# dem Durchgangsarzt
# zugewiesen
# arbeitsunfähig seit
# 251.04.15|
# voraussichtlich arbeitsunfähig
# bis einschließlich oder letzter
# Tag der Arbeitsunfähigkeit
# festgestellt am
# 27.11.16
# Ausfertigung zur Vorlage beim Arbeitgeber
# Vertragsarztstempel / Unterschrift des Arztes
# Muster 1b (1.2016)
# Nr.
# 51345
# ·
# www.praxisformulare.de
# ·
# Ohm
# Print
# Consulting
# GmbH
# ·
# Freisenbergstr.
# 21.58513
# Lüdenscheid
# Bianca Biesler, Amtsstraße 63,65195 Wiesbaden
# Lebensgut Versicherungsgesellschaft
# Brüsseler Straße 1
# 67657 Kaiserslautern
# Schadennummer: 890-LV-256348-BB
# Versicherungsnummer:
# 300/LV/852741/2B
# Wiesbaden, der 06.04.2010
# Sehr geehrte Damen und Herren,
# da ich nun schon mehrmals Fragebögen beantwortet und Bilder zu gesendet
# habe, möchte ich gerne die erstattungspflichtigen finanziellen Folgen erhalten.
# Nun habe ich erfahren, dass Herr. Godmann die Schuld abstreitet und eine
# Falschaussage abgegeben hat. Deshalb möchte ich Sie bitten den Tatbestand
# nochmals genau zu untersuchen.
# Meine Versicherung sieht die Schuld eindeutig bei Ihrem Mandanten und
# wartet auf seine Rückmeldung!
# Ich erwarte eine Antwortet binnen 14 Tagen.
# Mit freundlichen Grüßen,
# Sabine Kallmeyer, Im Bachgarten 60,50259 Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 27.08.2013
# Erklärung
# zu der Lebensversicherung
# 8798wA1
# Sehr geehrte Damen und Herren,
# hierdurch teile ich Ihnen mit, dass ich die o.g. Versicherung zum nächstmöglichen Zeitpunkt
# beitragsfrei weiterführen möchte.
# Bitte teilen Sie mir den Rückkaufswert zum Änderungstermin sowie die Ablaufleistung mit.
# Für Ihre schnelle Bearbeitung danke ich Ihnen.
# Viele Grüße
# Sabine Kallmeyer
# Landeshauptstadt
# Wiesbaden
# Am Bürgerring 67,68433 Wiesbaden
# Kreisverwaltungsreferat
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Sehr geehrte Damen und Herren,
# Ihr Schreiben kann nicht bearbeitet werden, da
# X
# das Kennzeichen nicht/falsch angegeben wurde.
# Halterdaten nicht mit den Angaben der Kraftfahrzeugkartei übereinstimmen/fehlen.
# die Fahrzeug-Ident-Nr. auf Ihrem Vorgang falsch angegeben wurde.
# die Versicherungsbestätigungskarte nicht der per 01.04.2013 gesetzlich vorgeschriebenen
# Form entspricht.
# Von Ihnen liegt keine 29a Karte vor.
# X Anzeige eingegangen am:
# 19. 4.2015
# stillgelegt am:
# Neue Versicherungsbestätigung liegt vor mit Wirkung vom:
# von einem anderen Versicherer
# von Ihnen unter Nr.
# für den genannten Halter
# für einen anderen Halter
# Das Fahrzeug wurde am
# umgeschrieben.
# Mit freundlichen Grüßen
# i.A.
# Max Mustermann
# Manfred Meier, Hauptstraße 200,39524 Fischbeck
# Lebensgut Versicherungsgesellschaft
# Brüsseler Straße 1
# 67657 Kaiserslautern
# Mannheim, den 21.06.2013
# Betreff: Meldung Hochwasserschaden; Versicherungs-Nr. 030/98/24061990
# Sehr geehrte Damen und Herren,
# wie Sie sicherlich in den Medien verfolgt haben, ist durch das Elb-Hochwasser Anfang Juni nahe
# meines Wohnortes Fischbeck der Hauptdeich der Elbe gebrochen, wodurch Fischbeck innerhalb
# weniger Stunden komplett überflutet wurde. Dieser Deichbruch kam für mich völlig unerwartet und
# auch die örtlichen Behörden hatten keinerlei Warnungen vor der Möglichkeit eines solchen
# Ereignisses ausgesprochen. Ich hatte daher keinerlei Möglichkeit mich auf die Überflutung
# vorzubereiten und bewegliche Gegenstände entsprechend vor dem Eintreffen der Wassermassen zu
# entfernen, so dass auf meinem Grundstück die folgenden Schäden entstanden sind:
# .
# Wasserschaden am Gebäude; Schätzung laut Gutachter: 75.000 €
# .
# Totalschaden KFZ BMW 320d Baujahr 2003; Wert laut Schwacke-Liste: 11.600 €
# Fast vollständige Zerstörung meines Gartens; geschätzter Schaden: 15.000 €
# Vollständige Zerstörung meiner Gartenmöbel, bestehend aus folgenden Einzelpositionen
# o Tisch; Neupreis 599 ,- €
# O
# Sitzbank; Neupreis 489 ,- €
# 0
# 4 Stühle; Neupreis 699 ,- €
# 0
# Sonnenschirm; Neupreis 199 ,- €
# 0
# Kugelgrill; Neupreis 149 ,- €
# Ich bitte Sie mir mitzuteilen, inwieweit Sie diese Schäden im Rahmen meiner Hausratversicherung
# (Versicherungs-Nr. 030/98/24061990) begleichen werden und wie das weitere Vorgehen dazu
# aussehen wird. Die Belege würde ich dann entsprechend nachreichen. Ich hatte bereits versucht
# diese Information von Ihnen telefonisch zu erhalten, allerdings hat der Sachbearbeiter darauf
# bestanden, dass ich Ihnen hierzu einen formalen Brief schreiben muss. Ich finde ein derartig extrem
# bürokratisches Vorgehen in der aktuellen Situation, in der die vom Hochwasser betroffenen Familien
# schon genug um die Ohren haben, unverständlich und hoffe nun zumindest auf eine kulante
# Schadensabwicklung ihrerseits.
# Mit freundlichen Grüßen
# Manfred Meier
# Klaus-Peter Schmidt
# Rosenstraße 88
# 50733 Köln
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Dienstag, den 25.06.2012
# Adressänderung ab sofort
# Sehr geehrte Damen und Herren,
# bitte ändern Sie die Adresse. Ab sofort gilt:
# Tulpenweg 9
# 50733 Köln
# Mit den besten Empfehlungen
# R.S. Schmidt
# Hinweis: Umschlag bitte aufbewahren, siehe Rückseite!
# Absender:
# Zugestellt am
# (Datum, ggf. Uhrzeit, Unterschrift)
# 01.07.20
# Deutsche Post
# Förmliche Zustellung
# 0 1. 07.20
# Weitersenden innerhalb des
# Aktenzeichen
# Bezirks des Amtsgerichts
# Bezirks des Landgerichts
# *Inlands
# Bei der Zustellung zu beachtende Vermerke
# Ersatzzustellung ausgeschlossen
# Keine Ersatzzustellung an:
# Nicht durch Niederlegung zustellen
# Mit Angabe der Uhrzeit zustellen
# Krankenkasse bzw. Kostenträger
# IKK gesund: plus
# Arbeitsunfähigkeits-
# Name, Vorname des Versicherten
# Oehmichen
# bescheinigung
# 1
# Nora
# Klamannstraße 26
# 25.09am80
# Erstbescheinigung
# D 71154 Nufringen
# Folgebescheinigung
# Kostenträgerkennung
# 550278302
# Versicherten-Nr.
# H738024428
# Arzt-Nr.
# Datum.
# 852475539 .27.05.12
# Arbeitsunfall, Arbeitsunfall-
# dem Durchgangsarzt
# folgen, Berufskrankheit
# zugewiesen
# 28.08 | 15
# arbeitsunfähig seit
# voraussichtlich arbeitsunfähig
# |31.03|15
# bis einschließlich oder letzter
# Tag der Arbeitsunfähigkeit
# 21.12 | 18
# festgestellt am
# Vertragsarztstempel / Unterschrift des Arztes
# Muster 1b (1.2016)
# Ausfertigung zur Vorlage beim Arbeitgeber
# Nr.
# 51345
# ·
# www.praxisformulare.de
# ·
# Ohm
# Print
# Consulting
# GmbH
# ··
# Freisenbergstr.
# 21.58513
# Lüdenscheid
# Franz Mustermann
# Musterweg 7
# 23456 Musterhausen
# Deutschland
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Montag, den 16.12.2014
# Änderung der begünstigten Person im Todesfall
# Guten Tag,
# hiermit wird die Änderung des Bezugsrechts für die Lebensversicherung-Nr. 422778 beantragt.
# · im Erlebensfall:
# die versicherte Person
# .
# im Todesfall:
# Hannah Mustermann, geb. 14.08.1980
# Diese Änderung des Bezugsrechts erlangt erst dann Gültigkeit, wenn dieses Formular unterschrieben
# bei uns eingegangen ist.
# Freundliche Grüße
# F- Mustermann
# Stadt Köln
# Der Oberbürgermeister
# Amt für öffentliche Ordnung
# Rheinweg 30
# ober.buergermeister@stadt-koeln.de
# www.stadt-koeln.de
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# 27.08.2013
# Bescheid zur Anzeige gem.§ 29 c StVZO
# Kraftfahrt Vers. Nr.: 6975
# Amtliches Kennzeichen K-UW-11
# Fahrzeughalter: Marianne Rosenberg
# Sehr geehrte Damen und Herren,
# aufgrund Ihrer o. g. Anzeige gem. § 29 c StVZO habe ich die Fahndung nach dem Fahrzeug eingeleitet.
# Sobald mir eine Mitteilung diesbezüglich vorliegt, erhalten Sie von hier unaufgefordert Nachricht.
# Mit freundlichen Grüßen
# i. A. Peter Lustig
# Europäische Gemeinschaft
# Bundesrepublik Deutschland
# D
# Zulassungsbescheinigung Teil II
# (Fahrzeugbrief)
# CBNAETENCTBOTO 3a perucTpauna - yacT Il / Permiso de circulación. Parte Il / Osvědčení o registraci - Část l / Registreringsattest. Del Il / Registreerimistunnistus. Osa Il /
# Acta EUROoplag/Hitonok . Mo II / Registration certificate. Part II / Certificat d'immatriculation. Partie Il / Prometna dozvola Il / Carta di circolazione. Parte Il /
# Registracijas aplieciba. Il. dala / Registracijos liudijimas. Il dalis / Forgalmi engedély. Il. Rész / Certifikat ta' Registrazzjoni. It-Il Parti / Kentekenbewijs. Deel Il /
# Dowód Rejestracyjny. Część II / Certificado de matrícula. Parte Il / Certificat de înmatriculare Partea Il / Osvedčenie o evidencii. Čast' Il / Prometno dovoljenje. Del II /
# Rekisteröintitodistus. Osa Il / Registreringsbeviset. Del II
# Diese Bescheinigung nicht im Fahrzeug aufbewahren!
# A
# Amtliches Kennzeichen
# B
# Datum der Erstzulassung
# 20.11.2019
# des Fahrzeugs
# (1)
# Anzahl der Vorhalter
# 0
# (1)
# Anzahl der Vorhalter
# C.3.1
# Name oder Firmenname
# C.6.1
# C.3.2
# Vorname(n)
# C.6.2
# C.3.3
# Anschrift zum Zeitpunkt
# der Ausstellung der
# C.6.3
# Bescheinigung
# C.4c
# 20.11.2019
# Der Inhaber der Zulassungsbescheinigung wird nicht als Eigentümer des Fahrzeugs ausgewiesen.
# Datum
# Datum
# -
# DE
# SECURITY
# CO
# SECURITY
# Ls1xZLyLY0
# Nur zur Nutzung des Sicherheitscodes
# im internetbasierten Zulassungsver-
# FN604683
# fahren freilegen. Dokument nur
# unbeschädigt gültig.
# (Nummer der Zulassungsbescheinigung)
# (Fahrzeug-Identifizierungsnummer als Barcode)
# D.1
# Marke
# VOLKSWAGEN, VW
# (23) Raum für interne Vermerke des Herstellers
# Typ
# AU
# D.2
# Variante
# GAC4DKTBXO
# 2020000346 BQ19VE DEU710 COC JA
# Version
# FD7FD7GC003S4BFON1ML1EVR2NA
# 23299146
# HUZ543 31968 AL 132
# D.3
# Handelsbezeichnung(en)
# GOLF
# (2)
# Hersteller-Kurzbezeichnung VOLKSWAGEN - VW
# 183
# (2.1)
# Code zu (2)
# 0603
# (2.2)
# Code zu D.2 mit
# CCS001482
# Prüfziffer
# E
# Fahrzeug-Identifizierungs-
# WVWZZZAUZLWO74971
# (3)
# Prüfziffer zur Fahrzeug-
# Identifizierungsnt.
# 7
# nummer
# Fahrzeugklasse
# M 1
# (4) Art des AC
# 1) Aufbaus
# Bezeichnung der Fahrzeug-
# Fz . z. Pers.bef.b. 8 Spl.
# (24) Diese Bescheinigung wurde für das nebenstehend beschriebene Fahr-
# 5)
# klasse und des Aufbaus
# zeug ausgegeben durch (Zulassungsbehörde bzw. Genehmigungsinhaber):
# Kombilimousine
# SCHWARZ
# VOLKSWAGEN AG
# R
# arbe des Fahrzeugs
# (11) Code |
# ppa.
# P.1
# Hubraum in cm3
# 1984
# P.2
# Nennleistung in kW
# 180
# 5000
# 13.11.2019
# P.4
# Nenndrehzahl bei min"
# P.3
# Kraftstoffart oder
# Code
# Energiequelle
# Benzin
# 10) zu P3
# 0001
# Datum
# K
# Nummer der EG-Typ-
# genehmigung oder ABE
# e1*2007/46*0623*42
# 6
# Datum
# 25.09.2019
# zu K
# Unterschrift:
# 17)
# Merkmal zur Betriebs-
# erlaubnis
# K
# 25)
# Zusätzliche Vermerke der Zulassungsbehörde:
# (maschinenlesbare Nummer der Zulassungsbescheinigung)
# BUNDES
# &
# DRUCKEREI
# 2017
# NEUSCHADEN
# Kunden-Nr. 03.823756
# Franz Mustermann
# Musterweg 7
# 23456 Musterhausen
# Deutschland
# Produkt:
# Haftpflichtversicherung (Gewerbe/Industrie)
# VS.Nr .:
# 394863986780
# Risiko:
# diverse Risiken gem. Objektliste
# Unfallstelle:
# Goldhähnchenweg, 67634 Rotenbach
# Anspruchsteller:
# Franz Mustermann
# Schaden-Nr (eigen) 01743683
# Sachbearbeiter: Klaus G.
# Schaden (VN): Herabfallender Putz
# Telefon 040/43756
# Fax 040/438639
# Schadenseintritt:
# 16.12.2005
# Eingang:
# 30.01.2006
# Meldung:
# 31.01.2006
# Status:
# offen
# Kosten:
# 640,39
# Zahlungen:
# 0,00
# Reserve:
# 640,39
# Art:
# Sachschaden-AH
# Ursache:
# Mangelhafte Einrichtung
# Schilderung:
# Herabfallender Putz vom Gebäude hat die Windschutzscheibe
# eines VW-Transporters zerbrochen
# m, ggr.
# . Uhrzeit, U
# Unterschni
# 190820
# Förmliche Zustellung
# Aktenzeichen
# 19. 08.20
# Weitersenden innerhalb des
# Bezirks des Amtsgerichts
# Bezirks des Landgerichts
# X Inlands
# Bei der Zustellung zu beachtende Vermerke
# Ersatzzustellung ausgeschlossen
# Keine Ersatzzustellung an:
# Nicht durch Niederlegung zustellen
# Mit Angabe der Uhrzeit zustellen
# Hans Kallmeyer
# Dienstag, den 09. Feb. 2012, Pulheim
# Im Bachgarten 60
# 50259 Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Sehr geehrte Damen und Herren,
# hiermit kündige ich meine Lebensversicherung Nr. 21032153 und Nr. 130214255 zum
# Monatsende.
# Den Rückkaufwert einschließlich Gewinnen, bitte ich Sie auf mein Konto bei der
# Sparkasse Pulheim, das Ihnen bekannt ist, zu erstatten.
# Mit freundlichen Grüßen
# Kamuys
# Hinweis: Umschlag bitte auf-
# bewahren, siehe Vorblatt!
# Zugestellt am
# (Datum, ggf. Uhrzeit, Unterschrift)
# Deutsche Post .
# Förmliche Zustellung
# 0 6. 07.20
# 06.02. 20
# Ihr Versicherungsmakler!
# Partner & Co - Versicherungsmakler
# Lindenstraße 7
# 68643 Vierstadt
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Vierstadt, 11.09.2012
# Betr.: Änderung der Bezugsberechtigung für Lebensversicherungen
# VSNR: 985236
# Verehrte Damen und Herren,
# hiermit wird gebeten, die Bezugsberechtigten aus o.a. Versicherung zu ändern:
# neu:
# die noch lebenden Kinder der versicherten Person zu gleichen Teilen.
# Ist ein Kind verstorben, erhält das noch lebende Kind das gesamte Guthaben.
# Leben beide Kinder nicht mehr, fällt die Versicherungsleistung in den Nachlass der versicherten Person.
# Ban Becker
# Unterschrift Versicherungsnehmer:
# Wir bitten uns die Änderung mitzuteilen.
# Mit den besten Empfehlungen
# V. Maier
# JOHANNA MAIER, PARTNER & CO
# Krankenhaus ABC
# Auf dem Weg der Besserung 101
# 89560 Berlin
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Aufn-Nr: 10151703
# Aufn-Datum: 18.02.14
# Zimmer: 106
# KOSTENÜBERNAMEANTRAG
# Information Versicherter:
# Krankenversicherten-Nr .:
# 00428479
# Versichertenstatus:
# 1000
# Gültigkeit KVK-Karte:
# KB int. KZ des Versich .:
# Hauptversicherter:
# Patient selbst
# Fallnummer
# Aktenzeichen
# Kostenübernahme-Beginn:
# Information Patient:
# Name:
# Griffin
# Vorname:
# Peter
# Geburtsdatum:
# 22.11.1985
# Anschrift:
# 55783 Buxdehude, Parkstrasse 6
# Titel:
# Länder-Kz .:
# D
# Aufnahme:
# Aufnahmetag/-zeit:
# 18.02.14, 23:30
# Aufnahmegrund:
# 0107
# Fachabteilung:
# 0100
# Vor. Behandlungsdauer:
# bis 11.03.2014
# Arzt-Nr. einw.Arzt:
# 4713
# Veranl . KHS:
# Veranl. Stelle:
# Aufnahme-und Einweisungsdiagnose:
# Einweisungsdiagnose:
# Coma hepaticum
# Aufnahmediagnose(n):
# k72.0 / K76.7 / K70.3
# Sie werden gebeten, die Kosten der stat. Behandlung zu übernehmen und innerhalb von 3 Tagen eine
# Kostenübernahmeerklärung zu übersenden. Im Ablehnungsfalle wird eine sofortige Nachricht unter
# Angabe der Gründe erbeten.
# (Dokument wurde maschinell erstellt und ist ohne Unterschrift gültig)
# Hans Kallmeyer
# Im Bachgarten 60
# 50259 Pulheim
# Insiders Versicherungen
# Brüsseler Straße 100
# 67657 Kaiserslautern
# Pulheim, 6.8.13
# Einen schönen guten Tag,
# ab nächstem Monat lautet meine neue Anschrift:
# Hirschenbergstr. 16
# D-87541 Hindelang
# Meine Bankverbindungen bleiben bis auf weiteres erhalten.
# Viele Grüße
# 1. callmeyer

# %%
def get_text_chunks(text):
    text_splitter = TokenTextSplitter(chunk_size=1200, chunk_overlap=0)
    texts = text_splitter.split_text(text)
    return texts[0]

# %% [markdown]
# # Find the embeddings for the documents

# %%
def get_embeddings(text_data):
    embeddings = OpenAIEmbeddings()
    data_text = [x['text'] for x in text_data]
    vectors = embeddings.embed_documents(data_text)
    return vectors

train_embeddings = get_embeddings(train_text)
test_embeddings = get_embeddings(test_text)
len(train_embeddings)
len(test_embeddings)
# Out:
# 280

# %% [markdown]
# # Apply KMeans clustering

# %%
from sklearn import preprocessing
# Applying KMeans clustering on cleaned data with range of clusters
inertia = []

# Initialize lists to store silhouette scores
silhouette_scores = [0] * 30
range_n_clusters = list(range(2, 30))
for k in range(2, 30):
    kmeans = KMeans(n_clusters=k, random_state=7).fit(preprocessing.normalize(train_embeddings))
    inertia.append(kmeans.inertia_)
    silhouette_avg = silhouette_score(train_embeddings, kmeans.labels_)
    silhouette_scores[k] = silhouette_avg

plt.figure(figsize=(8, 4))
plt.plot(range(2, 30), inertia, marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# Plot silhouette scores
silhouette_scores = silhouette_scores[2:30]
plt.plot(range_n_clusters, silhouette_scores, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette score')
plt.title('Silhouette Method for Optimal K')
plt.show()

# %% [markdown]
# # From the above graph, we can see that the elbow is at 17. So, we will use 17 clusters for our KMeans clustering

# %%
# Applying KMeans clustering on cleaned data with 8 clusters
k_optimal = 17
kmeans_optimal = KMeans(n_clusters=k_optimal, random_state=7).fit(preprocessing.normalize(train_embeddings))

# %%
test_labels = kmeans_optimal.predict(preprocessing.normalize(test_embeddings))

# %% [markdown]
# # Processing the data

# %%
import pandas as pd
import os
for i, row in enumerate(test_text):
    index = row['source'].find(".")
    print(test_text[i]['source'])
    test_text[i]['source'] = row['source'][:index+1]
    print(test_text[i]['source'])
df = pd.DataFrame(os.path.basename(row['source']) for row in test_text)
df['label']=test_labels
df
# Out:
# dcc4a106ec167c5624a2b25430f042fd.
# dcc4a106ec167c5624a2b25430f042fd.
# e0abc9a25ac589aedafbbb26ec5ece3d.
# e0abc9a25ac589aedafbbb26ec5ece3d.
# 25a7a30c448e90fe7a74a8cf63d9c974.
# 25a7a30c448e90fe7a74a8cf63d9c974.
# e2620553c53f7636ed76c4f45d9a679c.
# e2620553c53f7636ed76c4f45d9a679c.
# 57ab20f06d415a76b461cc120006cd2d.
# 57ab20f06d415a76b461cc120006cd2d.
# 44c71bf12711a784d99a2ab2a2968778.
# 44c71bf12711a784d99a2ab2a2968778.
# ef10fc8b264be83ec52bed6a2422d80e.
# ef10fc8b264be83ec52bed6a2422d80e.
# 59fb71f178f247523719897bb6127a66.
# 59fb71f178f247523719897bb6127a66.
# 56f44e496f67769a69bed6500fd7f694.
# 56f44e496f67769a69bed6500fd7f694.
# 412e0942006af3c01d8ea8a9ba481268.
# 412e0942006af3c01d8ea8a9ba481268.
# aa87d3aecf507f0f1e13a00b8b57429f.
# aa87d3aecf507f0f1e13a00b8b57429f.
# 21ce753349be82d5c1c4ff26057f6158.
# 21ce753349be82d5c1c4ff26057f6158.
# 4072108702e781154aac5cf7895b6ce7.
# 4072108702e781154aac5cf7895b6ce7.
# d4bb59de624ba8c6eb8a25dff75a58fa.
# d4bb59de624ba8c6eb8a25dff75a58fa.
# ae51f6126868d4b2752b9410c15a6815.
# ae51f6126868d4b2752b9410c15a6815.
# 8fb0d020110d20a7f82ae6706cec7a4a.
# 8fb0d020110d20a7f82ae6706cec7a4a.
# 20304706a6decc1775f69f7c00786c0d.
# 20304706a6decc1775f69f7c00786c0d.
# 85d67c2470a99e9921dd451b9c52421f.
# 85d67c2470a99e9921dd451b9c52421f.
# edd1c44aeeccb8fb3efd7991c0c5cca7.
# edd1c44aeeccb8fb3efd7991c0c5cca7.
# a719fc8b94ec3e59e250c08128a4fa78.
# a719fc8b94ec3e59e250c08128a4fa78.
# 9ab7c55375f7b22ee50a73cc2fb7b864.
# 9ab7c55375f7b22ee50a73cc2fb7b864.
# 0be71a800166e8a60a3791102c558ec0.
# 0be71a800166e8a60a3791102c558ec0.
# c0aa2754ff1fdbcb688ba36b6003a813.
# c0aa2754ff1fdbcb688ba36b6003a813.
# 24b6eb215bac4eef4954d24ed6d21953.
# 24b6eb215bac4eef4954d24ed6d21953.
# fec330f839de21a2f3bc7ba0729b548b.
# fec330f839de21a2f3bc7ba0729b548b.
# cf4aee18dc031ae0c7a493fd9b63aefc.
# cf4aee18dc031ae0c7a493fd9b63aefc.
# ce2d7e0e90c61baaf5d31de0816ce3d0.
# ce2d7e0e90c61baaf5d31de0816ce3d0.
# 16ea433c44685375231fa7a488670604.
# 16ea433c44685375231fa7a488670604.
# a03d9dde336944f4ba58a9038c42fee6.
# a03d9dde336944f4ba58a9038c42fee6.
# 8249d4a55e1ebc289a22225fe64906cd.
# 8249d4a55e1ebc289a22225fe64906cd.
# e702cb206f3e62c7c225a85b4819f367.
# e702cb206f3e62c7c225a85b4819f367.
# 751debc083a0566ae52c7084acb07406.
# 751debc083a0566ae52c7084acb07406.
# 28593a7a8016aa07aa74ba6b16feb0fa.
# 28593a7a8016aa07aa74ba6b16feb0fa.
# 195339a633bd47b4c82afdcb9ed8ee94.
# 195339a633bd47b4c82afdcb9ed8ee94.
# 88ebd311f5a25b2c354285c6b0923d2a.
# 88ebd311f5a25b2c354285c6b0923d2a.
# 6f641c0d96b84661d471f72e75316cac.
# 6f641c0d96b84661d471f72e75316cac.
# 3038dd7c999379f4cbcc4efbf25911c8.
# 3038dd7c999379f4cbcc4efbf25911c8.
# 8be599c946e622212ee27a178a4dd75d.
# 8be599c946e622212ee27a178a4dd75d.
# cd6752e70f950e6d1045a55123f9b3ec.
# cd6752e70f950e6d1045a55123f9b3ec.
# ed418ebff2e250cc968294558cf7115e.
# ed418ebff2e250cc968294558cf7115e.
# 09222d2557144e0d02c9749362c70d88.
# 09222d2557144e0d02c9749362c70d88.
# 8ce8ed378ed4a10928b3fb7417fbf7f0.
# 8ce8ed378ed4a10928b3fb7417fbf7f0.
# a19e08ba1cc0d6a0e7005739ce789d69.
# a19e08ba1cc0d6a0e7005739ce789d69.
# dc8a06870df2d3e589a2d1981a901bda.
# dc8a06870df2d3e589a2d1981a901bda.
# b9649a6a11671e60bd0b8841b1ce5fa1.
# b9649a6a11671e60bd0b8841b1ce5fa1.
# 400f74ee3aeea7e12641d31680af2d4b.
# 400f74ee3aeea7e12641d31680af2d4b.
# 29f5b3c6f4221a468f2c837c6e508b66.
# 29f5b3c6f4221a468f2c837c6e508b66.
# 4bfa7735f7ba409c8b8fc80dbf019230.
# 4bfa7735f7ba409c8b8fc80dbf019230.
# ef0b5963d509331bb6b685856dc51f22.
# ef0b5963d509331bb6b685856dc51f22.
# 10843aea7577225706dddacb1c53747e.
# 10843aea7577225706dddacb1c53747e.
# 21a470fb604d18fb9f3f01aea9e32bc4.
# 21a470fb604d18fb9f3f01aea9e32bc4.
# a0ab30a54476b6115e2994e9e7ac5db3.
# a0ab30a54476b6115e2994e9e7ac5db3.
# 9c5b9c6d97459e1bfe04b9e9167a2779.
# 9c5b9c6d97459e1bfe04b9e9167a2779.
# 51ef87b7a2fa74c128bf6124774f7fee.
# 51ef87b7a2fa74c128bf6124774f7fee.
# 2784390d305ad2a5c9c16c977839061f.
# 2784390d305ad2a5c9c16c977839061f.
# 87502f2cde8e1714e7ab1b37b17bc89c.
# 87502f2cde8e1714e7ab1b37b17bc89c.
# c51a51367c1fcfaef886ab4d1941ee36.
# c51a51367c1fcfaef886ab4d1941ee36.
# 7d23ef822a3993cacaacd3832f1a8370.
# 7d23ef822a3993cacaacd3832f1a8370.
# 16fd0579d8d61e48bae244925e6b80a3.
# 16fd0579d8d61e48bae244925e6b80a3.
# 6c3aee907488ee14ab12c6150b75b9aa.
# 6c3aee907488ee14ab12c6150b75b9aa.
# ba6b814dff15b8ac3855c07b2e66dcb2.
# ba6b814dff15b8ac3855c07b2e66dcb2.
# c7082430968200a749812442de127ab2.
# c7082430968200a749812442de127ab2.
# 20cf0504fcb431feded254d566c91f96.
# 20cf0504fcb431feded254d566c91f96.
# 3720e69815ff303ee3927f40a40bca80.
# 3720e69815ff303ee3927f40a40bca80.
# c237a8d6e99df08927516b67838d1fb2.
# c237a8d6e99df08927516b67838d1fb2.
# e3676e1883adea7be130555e31bf0916.
# e3676e1883adea7be130555e31bf0916.
# 0f50c0cefa61239686d991bc8b5d9a39.
# 0f50c0cefa61239686d991bc8b5d9a39.
# 732482f6692cf3afd85e76d3d3a2ae7b.
# 732482f6692cf3afd85e76d3d3a2ae7b.
# a7155639e598329ab79f2ad2afcc69b0.
# a7155639e598329ab79f2ad2afcc69b0.
# 4a087b4b89fa9eefc6fa130fef054bcb.
# 4a087b4b89fa9eefc6fa130fef054bcb.
# f901cdd996f268b203e13cd86ae83faf.
# f901cdd996f268b203e13cd86ae83faf.
# 34d8b8beeb8505c072b0cd903f07ac42.
# 34d8b8beeb8505c072b0cd903f07ac42.
# 0866dfbfcea368bd0c6ead1bffffd9df.
# 0866dfbfcea368bd0c6ead1bffffd9df.
# dd890f42a3495c416170a33149b8b243.
# dd890f42a3495c416170a33149b8b243.
# aa8337ba45d03bb94206532c8f8fe3d5.
# aa8337ba45d03bb94206532c8f8fe3d5.
# 24dc200f780a719b9284f84ac71f07c1.
# 24dc200f780a719b9284f84ac71f07c1.
# f39ae106b51614868f1bc7ccfdec3826.
# f39ae106b51614868f1bc7ccfdec3826.
# ef737967365cbf8a65f76be0c884fc4c.
# ef737967365cbf8a65f76be0c884fc4c.
# f8b69343787e41a8f178fd88b5e7c9a3.
# f8b69343787e41a8f178fd88b5e7c9a3.
# 5b94dcc096621efd6a367de3e3d73e9c.
# 5b94dcc096621efd6a367de3e3d73e9c.
# e8416d63b6c15a83c6dbd4349588c0b5.
# e8416d63b6c15a83c6dbd4349588c0b5.
# 4348c1152ec8f94c7d93240452a48e5e.
# 4348c1152ec8f94c7d93240452a48e5e.
# 90a3891a50e069f50785fe0449843e9c.
# 90a3891a50e069f50785fe0449843e9c.
# 6480282f95bbfb9902d3f4246d8a8884.
# 6480282f95bbfb9902d3f4246d8a8884.
# a3bcb1bc696bb77e4f78201b107a2229.
# a3bcb1bc696bb77e4f78201b107a2229.
# cb3f96e4b538a1b75e9999de596aec40.
# cb3f96e4b538a1b75e9999de596aec40.
# b4e3eb0a50655cf021d5e2dab384cd28.
# b4e3eb0a50655cf021d5e2dab384cd28.
# bdae535f23ae6198ec7187cccf2c7f76.
# bdae535f23ae6198ec7187cccf2c7f76.
# edebae2f7d8f67c2a1412a02a9ec0220.
# edebae2f7d8f67c2a1412a02a9ec0220.
# 33301f9d6dae748b04d8d03575102947.
# 33301f9d6dae748b04d8d03575102947.
# e7ee310c4bb0be675b3b79effb2b4e0a.
# e7ee310c4bb0be675b3b79effb2b4e0a.
# 04b38de2d28aed9eaf7a837c9e269c9c.
# 04b38de2d28aed9eaf7a837c9e269c9c.
# a9975390266a82e69532dabdcc3e3fda.
# a9975390266a82e69532dabdcc3e3fda.
# 323d0c0d2f5bc3ecdf3616728dbd96f2.
# 323d0c0d2f5bc3ecdf3616728dbd96f2.
# ba50570f33bf98f494e19d7879787664.
# ba50570f33bf98f494e19d7879787664.
# f963bd7251198bf9e897603031f25724.
# f963bd7251198bf9e897603031f25724.
# dabcbc1bdf50a9c785d355e68429be0a.
# dabcbc1bdf50a9c785d355e68429be0a.
# 505fdd52ca83335a4d93a1d91bfecdd1.
# 505fdd52ca83335a4d93a1d91bfecdd1.
# ce178f510ce657f0cad7def0dad24bab.
# ce178f510ce657f0cad7def0dad24bab.
# 9b14ad20260afe252251e580df17e778.
# 9b14ad20260afe252251e580df17e778.
# abb8c497cf7677446b19dd1e293eb2c2.
# abb8c497cf7677446b19dd1e293eb2c2.
# 316e193c21eaec9eb0137941e207b5ba.
# 316e193c21eaec9eb0137941e207b5ba.
# 105340ccee50ddb5e6299d8ec572e598.
# 105340ccee50ddb5e6299d8ec572e598.
# f9ab90aa164dc172d578cbbf9a103fec.
# f9ab90aa164dc172d578cbbf9a103fec.
# eac864a70681149430ae5ea68b756ae6.
# eac864a70681149430ae5ea68b756ae6.
# dd0f304fc7c7521f3d71d1271a237e25.
# dd0f304fc7c7521f3d71d1271a237e25.
# f8682eeb69fb2e7bea080391c5fdcb0d.
# f8682eeb69fb2e7bea080391c5fdcb0d.
# c77e78eb039cb4fb854002c92970cbaa.
# c77e78eb039cb4fb854002c92970cbaa.
# 2c580178d4cf35dd294a6cf0e0024460.
# 2c580178d4cf35dd294a6cf0e0024460.
# ed1ec71e94442686bb91274504be0979.
# ed1ec71e94442686bb91274504be0979.
# 009ae686ab201cbc03789d40aa89bbc2.
# 009ae686ab201cbc03789d40aa89bbc2.
# 52ef32c08f01c0b4069b869e57c617ed.
# 52ef32c08f01c0b4069b869e57c617ed.
# 21b67b25d35834337bc85889c2dd1ce6.
# 21b67b25d35834337bc85889c2dd1ce6.
# 6206e9833b7101b58e05bfe5edc9f0c8.
# 6206e9833b7101b58e05bfe5edc9f0c8.
# bfc1fd0384a12dc206d37f78888df2a6.
# bfc1fd0384a12dc206d37f78888df2a6.
# 32b787c0b89b2497661b97fead93df42.
# 32b787c0b89b2497661b97fead93df42.
# ff75e58e64f950911ea5faf869170ba0.
# ff75e58e64f950911ea5faf869170ba0.
# 7ec4c2137a8a1afb1f32ef8be75c8b1b.
# 7ec4c2137a8a1afb1f32ef8be75c8b1b.
# 7f051d85b3b866d0b2b4c583c29e0fdd.
# 7f051d85b3b866d0b2b4c583c29e0fdd.
# 292c9baa2347e3199adfb7715832372f.
# 292c9baa2347e3199adfb7715832372f.
# 3545f00afbba4684a7734ff636637f13.
# 3545f00afbba4684a7734ff636637f13.
# 1e4c436b43e85c1387a2b6b4a050be77.
# 1e4c436b43e85c1387a2b6b4a050be77.
# 4a6775708fb43ed1a7d6ab1de2cf5e1f.
# 4a6775708fb43ed1a7d6ab1de2cf5e1f.
# 50e92ae994a329480c8e4817df2d0301.
# 50e92ae994a329480c8e4817df2d0301.
# 9d10581de2fa1d91faf499f8d852a7ac.
# 9d10581de2fa1d91faf499f8d852a7ac.
# 29fec1b0e9dee28f3a2de0d8ed52a0a2.
# 29fec1b0e9dee28f3a2de0d8ed52a0a2.
# f540e0faf891052c2dad7ad4a780b09f.
# f540e0faf891052c2dad7ad4a780b09f.
# c9c514db1d050e4c705f9c06d61b181d.
# c9c514db1d050e4c705f9c06d61b181d.
# 38804b3ac13eae957308c32c0403ff4b.
# 38804b3ac13eae957308c32c0403ff4b.
# 2be6fab4d76e61a5310688154e8a5207.
# 2be6fab4d76e61a5310688154e8a5207.
# 9e3cd95ecde2bd45ace3e35ba894bc36.
# 9e3cd95ecde2bd45ace3e35ba894bc36.
# a131f67a477f55116adfd8520e2aa887.
# a131f67a477f55116adfd8520e2aa887.
# 5d58ddadbae8656e548d5d4db3760740.
# 5d58ddadbae8656e548d5d4db3760740.
# 478a97808b9baf659e65e21e301147da.
# 478a97808b9baf659e65e21e301147da.
# f96e8ee69f04f993bb5fa41004801a8f.
# f96e8ee69f04f993bb5fa41004801a8f.
# e94e2694d5611d166f709ed6f22ff97f.
# e94e2694d5611d166f709ed6f22ff97f.
# 04229aa14fedd5de427f25fb50409d5b.
# 04229aa14fedd5de427f25fb50409d5b.
# 875928557c24b2cbd2c5c138700a9443.
# 875928557c24b2cbd2c5c138700a9443.
# 05e96562e19e2fed2b6458f24196f53a.
# 05e96562e19e2fed2b6458f24196f53a.
# aa69f293f1ca85a43513ff732978ddd8.
# aa69f293f1ca85a43513ff732978ddd8.
# beb641870c3e11dad901eec2d61e92c5.
# beb641870c3e11dad901eec2d61e92c5.
# d66b889983d81e5bd5e9cdb59d2a8483.
# d66b889983d81e5bd5e9cdb59d2a8483.
# 37b82c3f62a12c76ebf2ef75aa5336fd.
# 37b82c3f62a12c76ebf2ef75aa5336fd.
# 1c41c2862fc9a86a0a9f4d4f2bc370cc.
# 1c41c2862fc9a86a0a9f4d4f2bc370cc.
# d2391783fa8b889b313f630baaba0a05.
# d2391783fa8b889b313f630baaba0a05.
# f7801d95f48033d45d5887ca08903dd4.
# f7801d95f48033d45d5887ca08903dd4.
# 542f1d6263ad49c727d39149f0590b33.
# 542f1d6263ad49c727d39149f0590b33.
# a823104a64da51a1cedd8c5563532715.
# a823104a64da51a1cedd8c5563532715.
# e1d0ec26cbd3e7ecec4ca37ea0b66717.
# e1d0ec26cbd3e7ecec4ca37ea0b66717.
# 569b346029795185bb747626e2ed278d.
# 569b346029795185bb747626e2ed278d.
# 442f98043133734788b35287393a30db.
# 442f98043133734788b35287393a30db.
# 4c9592165f8dbae97c48b62d459dda59.
# 4c9592165f8dbae97c48b62d459dda59.
# e58efff984d9c113a31bb2f17efdd035.
# e58efff984d9c113a31bb2f17efdd035.
# ed5cc73dfda9eee35ff0c6bacae7761e.
# ed5cc73dfda9eee35ff0c6bacae7761e.
# 462e31e1c98ca5e7dc06ee0b765b29ad.
# 462e31e1c98ca5e7dc06ee0b765b29ad.
# 544206e3b9adaf201e3ab42403beaa40.
# 544206e3b9adaf201e3ab42403beaa40.
# 45aa71af3617245ddb9c4ab23b443290.
# 45aa71af3617245ddb9c4ab23b443290.
# 16f1a12b8123d42657938cde7281395f.
# 16f1a12b8123d42657938cde7281395f.
# aad3cfc8ad630e56a4af7497dee2fee1.
# aad3cfc8ad630e56a4af7497dee2fee1.
# 73e26e078017d6c66a1ac2c4b8898e15.
# 73e26e078017d6c66a1ac2c4b8898e15.
# db8e16f27556278b3c3a03447524a77b.
# db8e16f27556278b3c3a03447524a77b.
# 89afef4114bfae49be3be8258fc6016a.
# 89afef4114bfae49be3be8258fc6016a.
# 67025a26468fd6481e2fa1aa78110368.
# 67025a26468fd6481e2fa1aa78110368.
# 414eca7356f70ec75f8a1fe86329a45e.
# 414eca7356f70ec75f8a1fe86329a45e.
# 7f3894b46a7e116afd0d0c7f30269db9.
# 7f3894b46a7e116afd0d0c7f30269db9.
# 92c3ac6358ea30a51969cbf2a38d1816.
# 92c3ac6358ea30a51969cbf2a38d1816.
# 2a8a6aaa0e025f7d83290c2b976831d6.
# 2a8a6aaa0e025f7d83290c2b976831d6.
# adbb9df0c261558406efcb6bc303f777.
# adbb9df0c261558406efcb6bc303f777.
# e07824635b9b7fd2d23968ccdebd60ca.
# e07824635b9b7fd2d23968ccdebd60ca.
# cd9dbb004eb98839ad322f4954f8a6e6.
# cd9dbb004eb98839ad322f4954f8a6e6.
# 592331eb5f023d1cc636dea14c90fd3a.
# 592331eb5f023d1cc636dea14c90fd3a.
# 2090151ffb061679014b02ec76e24766.
# 2090151ffb061679014b02ec76e24766.
# 7e36c2b7e7802c7ce376e2557148488a.
# 7e36c2b7e7802c7ce376e2557148488a.
# 0fcec757bb8499b0f64c9cbdf2992c49.
# 0fcec757bb8499b0f64c9cbdf2992c49.
# d43f969bf91c2492f903c834d34d09f3.
# d43f969bf91c2492f903c834d34d09f3.
# 2ae3d19eb69945c9a74a704413c48109.
# 2ae3d19eb69945c9a74a704413c48109.
# 342b8b5f83c29a96c8882fe0c8d9575e.
# 342b8b5f83c29a96c8882fe0c8d9575e.
# e9c157ce5012846ce0182547e20d94b0.
# e9c157ce5012846ce0182547e20d94b0.
# 5f6efd64c6733543b0de88d187c107d3.
# 5f6efd64c6733543b0de88d187c107d3.
# 8dbf8a6b73f3839496e613cb0a6e3ece.
# 8dbf8a6b73f3839496e613cb0a6e3ece.
# e567a9508abfe7508ba27d0172018cf0.
# e567a9508abfe7508ba27d0172018cf0.
# dd9d7835451c693da5d04de10f559e94.
# dd9d7835451c693da5d04de10f559e94.
# fcee4beb97428b99abaa2d2ea06237b7.
# fcee4beb97428b99abaa2d2ea06237b7.
# 51f792fcf46630673f30219ab9f62d78.
# 51f792fcf46630673f30219ab9f62d78.
# 8f3a2588f0eaa527e5391b9fd05a8b5b.
# 8f3a2588f0eaa527e5391b9fd05a8b5b.
# 3fc9dcc5b45431cccec27dcd114ea094.
# 3fc9dcc5b45431cccec27dcd114ea094.
# dedacab2f1a95a38edda7cdd82c7df4f.
# dedacab2f1a95a38edda7cdd82c7df4f.
# 4400559015c475d78f83c4f900a921fe.
# 4400559015c475d78f83c4f900a921fe.
# 9eac42384a76787e82284e8d94f11168.
# 9eac42384a76787e82284e8d94f11168.
# c5a5a8ea0cb4eff3a3af38475a9b75dd.
# c5a5a8ea0cb4eff3a3af38475a9b75dd.
# 96bb4fb3192fb80dcafe15dc4cd4f917.
# 96bb4fb3192fb80dcafe15dc4cd4f917.
# 24322c050b0c0cfe64ad76dde0d9d065.
# 24322c050b0c0cfe64ad76dde0d9d065.
# c33972f5f01d630f4413ceb0253771c8.
# c33972f5f01d630f4413ceb0253771c8.
# c47e0ed33df74df5355aca3def23a811.
# c47e0ed33df74df5355aca3def23a811.
# 94473b259deb4066b9ce75a191372139.
# 94473b259deb4066b9ce75a191372139.
# 623285c273d89e18e662d98343d9e33e.
# 623285c273d89e18e662d98343d9e33e.
# dce4c12303136da116135c6cdda88612.
# dce4c12303136da116135c6cdda88612.
# 929790f66dccbbfa03788409df928d5a.
# 929790f66dccbbfa03788409df928d5a.
# 4ab65383062a6390504a4e2dda80bbe2.
# 4ab65383062a6390504a4e2dda80bbe2.
# b2b429a396caa48854728733fc01b0c4.
# b2b429a396caa48854728733fc01b0c4.
# 8cbc2c2624131aa4d0c88c21ca0e8bda.
# 8cbc2c2624131aa4d0c88c21ca0e8bda.
# 11046dda65c3ce2b0283ae87608f1db0.
# 11046dda65c3ce2b0283ae87608f1db0.
# 51045d7ed23422866a6a7e8d7da9c949.
# 51045d7ed23422866a6a7e8d7da9c949.
# 78b7690a656adfb3513b66fda0bc77af.
# 78b7690a656adfb3513b66fda0bc77af.
# ba401daef1ae59c99ba4b67445eae8f4.
# ba401daef1ae59c99ba4b67445eae8f4.
# 1517fdbb628f0071761eea83f8bdfc09.
# 1517fdbb628f0071761eea83f8bdfc09.
# 802ebe3b5d5932664f40e0f16338eaa4.
# 802ebe3b5d5932664f40e0f16338eaa4.
# 5201babc4e4f7ee9609e739e39788ba6.
# 5201babc4e4f7ee9609e739e39788ba6.
# 59fed2636440af2cdf3f107b2f05397e.
# 59fed2636440af2cdf3f107b2f05397e.
# d02e2607234678db6105722b6ba23479.
# d02e2607234678db6105722b6ba23479.
# a7c0f200698f797d3816219f5f6758ac.
# a7c0f200698f797d3816219f5f6758ac.
# 55e0f894677e50e088154a583ac93d1e.
# 55e0f894677e50e088154a583ac93d1e.
# 5f947e6675316d7e19b54cd199e4da4b.
# 5f947e6675316d7e19b54cd199e4da4b.
# 02a423659dda5751a1c707a3639bb51f.
# 02a423659dda5751a1c707a3639bb51f.
# ea83b5954dc98f403d74d38e3401cad1.
# ea83b5954dc98f403d74d38e3401cad1.
# e89088fd0ce6b01829a2419a65c3b2b1.
# e89088fd0ce6b01829a2419a65c3b2b1.
# 3d9c3c0e9b3926e3165dc3b1fea506bf.
# 3d9c3c0e9b3926e3165dc3b1fea506bf.
# 955808f3498c9fa51924cc95eaed7e15.
# 955808f3498c9fa51924cc95eaed7e15.
# 06d95f3c880d15c7d477b2e44d5414c2.
# 06d95f3c880d15c7d477b2e44d5414c2.
# 8ddb7b9b389e7645bcfc3ec4b6379265.
# 8ddb7b9b389e7645bcfc3ec4b6379265.
# 809b45fcdddd040180696d916d165d04.
# 809b45fcdddd040180696d916d165d04.
# 8953db01557146b7fc4509dc1f3ac190.
# 8953db01557146b7fc4509dc1f3ac190.
# 29a3307c6a3337b573f46b1540bfd5eb.
# 29a3307c6a3337b573f46b1540bfd5eb.
# a25a258adb4566bdd1348d6855233746.
# a25a258adb4566bdd1348d6855233746.
# 3489d1b5cd6f509d388c50dfeb68fdc0.
# 3489d1b5cd6f509d388c50dfeb68fdc0.
# d44baac46790411799d69f899c5c331b.
# d44baac46790411799d69f899c5c331b.
# d07c4911ceafbe5db3f51a5ae2bbeba4.
# d07c4911ceafbe5db3f51a5ae2bbeba4.
# 1cb304ddc5613dfd495f675c3580c665.
# 1cb304ddc5613dfd495f675c3580c665.
# cdd1afe7112104dc45e43a8eab8f56fd.
# cdd1afe7112104dc45e43a8eab8f56fd.
# 528330593a196b6e3a061372645648e3.
# 528330593a196b6e3a061372645648e3.
# 167c57a595fccf6ca5a2e353379b864c.
# 167c57a595fccf6ca5a2e353379b864c.
# 731bf596b748629d95e1033d3be08634.
# 731bf596b748629d95e1033d3be08634.
# 2e26a5357d9ede57aaddc1565dbd28b6.
# 2e26a5357d9ede57aaddc1565dbd28b6.
# fd3695c58d9d14982ed81e9c7e9410fa.
# fd3695c58d9d14982ed81e9c7e9410fa.
# 0121968e60ef6b1d019f33de3c29dbce.
# 0121968e60ef6b1d019f33de3c29dbce.
# cd98660b02d4653538b4264e66a03dfd.
# cd98660b02d4653538b4264e66a03dfd.
# 5bb2ab3c7721a53e86ab82a798d13f45.
# 5bb2ab3c7721a53e86ab82a798d13f45.
# e55ae5116bc4f92d7beefc5b14d207e9.
# e55ae5116bc4f92d7beefc5b14d207e9.
# 0858bc389b91c53a4b9a513aeb62be78.
# 0858bc389b91c53a4b9a513aeb62be78.
# e0a622d3bafde3a827f4216f0e6891b3.
# e0a622d3bafde3a827f4216f0e6891b3.
# d2b422d868ca87ed2889703a9fdad636.
# d2b422d868ca87ed2889703a9fdad636.
# b14d062559096a09b09cc8c7565c5a46.
# b14d062559096a09b09cc8c7565c5a46.
# f2e447a8a7070ed0f91380dabe295475.
# f2e447a8a7070ed0f91380dabe295475.
# d0a0f7ba4df52421801caa0a6d261fac.
# d0a0f7ba4df52421801caa0a6d261fac.
# a46eb4eeb30f41c1877246db6960f5dd.
# a46eb4eeb30f41c1877246db6960f5dd.
# 11813c8e4bddbbe6cf3db3996c5750f3.
# 11813c8e4bddbbe6cf3db3996c5750f3.
# 0306e1882e336f5d0dd21b6be4c8fdc0.
# 0306e1882e336f5d0dd21b6be4c8fdc0.
# 728f3e9ed96b61936dc127357dbc2086.
# 728f3e9ed96b61936dc127357dbc2086.
# 5f0fa188f07f465be0885aabe09861ca.
# 5f0fa188f07f465be0885aabe09861ca.
# fefdbb0f4b1a7e4e942c3df9bb9d580a.
# fefdbb0f4b1a7e4e942c3df9bb9d580a.
# 37de9b77126b31220d134b033c4310e1.
# 37de9b77126b31220d134b033c4310e1.
# b6471cf1578ab01c5fa489cd31355ebe.
# b6471cf1578ab01c5fa489cd31355ebe.
# 5a993279e6abb1b88fe859f310a6abf9.
# 5a993279e6abb1b88fe859f310a6abf9.
# e7ef9425e411f2f2b774feb2aa13a01c.
# e7ef9425e411f2f2b774feb2aa13a01c.
# 31c9c97832d5dcba935cecd95390ab0c.
# 31c9c97832d5dcba935cecd95390ab0c.
# 06421deaea221ac8ec7ab5734adb5b01.
# 06421deaea221ac8ec7ab5734adb5b01.
# 33ff3fc8508db140a665acb20c3f5f29.
# 33ff3fc8508db140a665acb20c3f5f29.
# fbcd9214b10e74d5ec8b4687084afc78.
# fbcd9214b10e74d5ec8b4687084afc78.
# a8d8a58a799cd0d5298ff805adddd4cd.
# a8d8a58a799cd0d5298ff805adddd4cd.
# 827ddaab64c6e6883a1edfc5cd9ada51.
# 827ddaab64c6e6883a1edfc5cd9ada51.
# 6c878d335208ba7ee3172f8e226a555e.
# 6c878d335208ba7ee3172f8e226a555e.
# 6ce736f8680bdc40884fed47c3328718.
# 6ce736f8680bdc40884fed47c3328718.
# f7c8faccfa654f5415027d0b53c9c289.
# f7c8faccfa654f5415027d0b53c9c289.
# b0a5a06cc6e7ab098096cc8c24d4c213.
# b0a5a06cc6e7ab098096cc8c24d4c213.
# 3c3473137bba879ac6935f44c843598e.
# 3c3473137bba879ac6935f44c843598e.
# 3e976ed8eec7a2fed3201641ea397892.
# 3e976ed8eec7a2fed3201641ea397892.
# 7a1c9899a4724599b833a97dbd468ee0.
# 7a1c9899a4724599b833a97dbd468ee0.
# 10734a78b41531d43190d6ccddd1a6db.
# 10734a78b41531d43190d6ccddd1a6db.
# df24718ec60f232c4169e2637fb8e1c2.
# df24718ec60f232c4169e2637fb8e1c2.
# 8adf248a2da11f57dd67afc0146f6a25.
# 8adf248a2da11f57dd67afc0146f6a25.
# 4ac64881aacf6c4d1a53083ead040309.
# 4ac64881aacf6c4d1a53083ead040309.
# 05f5d0367eada6f82affd0e9ddad830f.
# 05f5d0367eada6f82affd0e9ddad830f.
# dedcbd66b5143ee75567a11d109441b4.
# dedcbd66b5143ee75567a11d109441b4.
# 69a9ab49e9f484fa8eed28f47b9c4a19.
# 69a9ab49e9f484fa8eed28f47b9c4a19.
# f0646b41a2b08b12093b4028914395ac.
# f0646b41a2b08b12093b4028914395ac.
# ec21736a67a68366ac663509359b7c5a.
# ec21736a67a68366ac663509359b7c5a.
# 1babf4d02b82740ef69faf94d3519029.
# 1babf4d02b82740ef69faf94d3519029.
# bc1dcfe1372f4f0f7692c7108cc9eff5.
# bc1dcfe1372f4f0f7692c7108cc9eff5.
# 879fc26b7fc361fff6bc7681ba235ad3.
# 879fc26b7fc361fff6bc7681ba235ad3.
# 0ad48f253bb1dbb7b9e17d71c27261e7.
# 0ad48f253bb1dbb7b9e17d71c27261e7.
#                                      0  label
# 0    dcc4a106ec167c5624a2b25430f042fd.     14
# 1    e0abc9a25ac589aedafbbb26ec5ece3d.     13
# 2    25a7a30c448e90fe7a74a8cf63d9c974.     10
# 3    e2620553c53f7636ed76c4f45d9a679c.      9
# 4    57ab20f06d415a76b461cc120006cd2d.      2
# ..                                 ...    ...
# 275  ec21736a67a68366ac663509359b7c5a.     12
# 276  1babf4d02b82740ef69faf94d3519029.      2
# 277  bc1dcfe1372f4f0f7692c7108cc9eff5.      9
# 278  879fc26b7fc361fff6bc7681ba235ad3.      7
# 279  0ad48f253bb1dbb7b9e17d71c27261e7.     12
#
# [280 rows x 2 columns]

# %%
result = {
    "clusters": {},
    "samples": {}
}

# %%
for index in range(k_optimal):
    result["clusters"]["cluster_" + str(index)] = "Cluster " + str(index)
for index, row in df.iterrows():
    result["samples"][row[0]] = "cluster_" + str(row['label'])
result
# Out:
# {'clusters': {'cluster_0': 'Cluster 0',
#   'cluster_1': 'Cluster 1',
#   'cluster_2': 'Cluster 2',
#   'cluster_3': 'Cluster 3',
#   'cluster_4': 'Cluster 4',
#   'cluster_5': 'Cluster 5',
#   'cluster_6': 'Cluster 6',
#   'cluster_7': 'Cluster 7',
#   'cluster_8': 'Cluster 8',
#   'cluster_9': 'Cluster 9',
#   'cluster_10': 'Cluster 10',
#   'cluster_11': 'Cluster 11',
#   'cluster_12': 'Cluster 12',
#   'cluster_13': 'Cluster 13',
#   'cluster_14': 'Cluster 14',
#   'cluster_15': 'Cluster 15',
#   'cluster_16': 'Cluster 16'},
#  'samples': {'dcc4a106ec167c5624a2b25430f042fd.': 'cluster_14',
#   'e0abc9a25ac589aedafbbb26ec5ece3d.': 'cluster_13',
#   '25a7a30c448e90fe7a74a8cf63d9c974.': 'cluster_10',
#   'e2620553c53f7636ed76c4f45d9a679c.': 'cluster_9',
#   '57ab20f06d415a76b461cc120006cd2d.': 'cluster_2',
#   '44c71bf12711a784d99a2ab2a2968778.': 'cluster_5',
#   'ef10fc8b264be83ec52bed6a2422d80e.': 'cluster_1',
#   '59fb71f178f247523719897bb6127a66.': 'cluster_12',
#   '56f44e496f67769a69bed6500fd7f694.': 'cluster_11',
#   '412e0942006af3c01d8ea8a9ba481268.': 'cluster_16',
#   'aa87d3aecf507f0f1e13a00b8b57429f.': 'cluster_1',
#   '21ce753349be82d5c1c4ff26057f6158.': 'cluster_12',
#   '4072108702e781154aac5cf7895b6ce7.': 'cluster_9',
#   'd4bb59de624ba8c6eb8a25dff75a58fa.': 'cluster_10',
#   'ae51f6126868d4b2752b9410c15a6815.': 'cluster_1',
#   '8fb0d020110d20a7f82ae6706cec7a4a.': 'cluster_13',
#   '20304706a6decc1775f69f7c00786c0d.': 'cluster_11',
#   '85d67c2470a99e9921dd451b9c52421f.': 'cluster_8',
#   'edd1c44aeeccb8fb3efd7991c0c5cca7.': 'cluster_12',
#   'a719fc8b94ec3e59e250c08128a4fa78.': 'cluster_15',
#   '9ab7c55375f7b22ee50a73cc2fb7b864.': 'cluster_0',
#   '0be71a800166e8a60a3791102c558ec0.': 'cluster_11',
#   'c0aa2754ff1fdbcb688ba36b6003a813.': 'cluster_11',
#   '24b6eb215bac4eef4954d24ed6d21953.': 'cluster_3',
#   'fec330f839de21a2f3bc7ba0729b548b.': 'cluster_0',
#   'cf4aee18dc031ae0c7a493fd9b63aefc.': 'cluster_7',
#   'ce2d7e0e90c61baaf5d31de0816ce3d0.': 'cluster_14',
#   '16ea433c44685375231fa7a488670604.': 'cluster_12',
#   'a03d9dde336944f4ba58a9038c42fee6.': 'cluster_8',
#   '8249d4a55e1ebc289a22225fe64906cd.': 'cluster_11',
#   'e702cb206f3e62c7c225a85b4819f367.': 'cluster_0',
#   '751debc083a0566ae52c7084acb07406.': 'cluster_1',
#   '28593a7a8016aa07aa74ba6b16feb0fa.': 'cluster_8',
#   '195339a633bd47b4c82afdcb9ed8ee94.': 'cluster_16',
#   '88ebd311f5a25b2c354285c6b0923d2a.': 'cluster_5',
#   '6f641c0d96b84661d471f72e75316cac.': 'cluster_8',
#   '3038dd7c999379f4cbcc4efbf25911c8.': 'cluster_10',
#   '8be599c946e622212ee27a178a4dd75d.': 'cluster_3',
#   'cd6752e70f950e6d1045a55123f9b3ec.': 'cluster_4',
#   'ed418ebff2e250cc968294558cf7115e.': 'cluster_7',
#   '09222d2557144e0d02c9749362c70d88.': 'cluster_0',
#   '8ce8ed378ed4a10928b3fb7417fbf7f0.': 'cluster_10',
#   'a19e08ba1cc0d6a0e7005739ce789d69.': 'cluster_0',
#   'dc8a06870df2d3e589a2d1981a901bda.': 'cluster_16',
#   'b9649a6a11671e60bd0b8841b1ce5fa1.': 'cluster_6',
#   '400f74ee3aeea7e12641d31680af2d4b.': 'cluster_8',
#   '29f5b3c6f4221a468f2c837c6e508b66.': 'cluster_4',
#   '4bfa7735f7ba409c8b8fc80dbf019230.': 'cluster_14',
#   'ef0b5963d509331bb6b685856dc51f22.': 'cluster_13',
#   '10843aea7577225706dddacb1c53747e.': 'cluster_11',
#   '21a470fb604d18fb9f3f01aea9e32bc4.': 'cluster_8',
#   'a0ab30a54476b6115e2994e9e7ac5db3.': 'cluster_13',
#   '9c5b9c6d97459e1bfe04b9e9167a2779.': 'cluster_14',
#   '51ef87b7a2fa74c128bf6124774f7fee.': 'cluster_10',
#   '2784390d305ad2a5c9c16c977839061f.': 'cluster_9',
#   '87502f2cde8e1714e7ab1b37b17bc89c.': 'cluster_11',
#   'c51a51367c1fcfaef886ab4d1941ee36.': 'cluster_4',
#   '7d23ef822a3993cacaacd3832f1a8370.': 'cluster_8',
#   '16fd0579d8d61e48bae244925e6b80a3.': 'cluster_8',
#   '6c3aee907488ee14ab12c6150b75b9aa.': 'cluster_14',
#   'ba6b814dff15b8ac3855c07b2e66dcb2.': 'cluster_0',
#   'c7082430968200a749812442de127ab2.': 'cluster_8',
#   '20cf0504fcb431feded254d566c91f96.': 'cluster_0',
#   '3720e69815ff303ee3927f40a40bca80.': 'cluster_12',
#   'c237a8d6e99df08927516b67838d1fb2.': 'cluster_0',
#   'e3676e1883adea7be130555e31bf0916.': 'cluster_13',
#   '0f50c0cefa61239686d991bc8b5d9a39.': 'cluster_5',
#   '732482f6692cf3afd85e76d3d3a2ae7b.': 'cluster_15',
#   'a7155639e598329ab79f2ad2afcc69b0.': 'cluster_4',
#   '4a087b4b89fa9eefc6fa130fef054bcb.': 'cluster_2',
#   'f901cdd996f268b203e13cd86ae83faf.': 'cluster_12',
#   '34d8b8beeb8505c072b0cd903f07ac42.': 'cluster_4',
#   '0866dfbfcea368bd0c6ead1bffffd9df.': 'cluster_4',
#   'dd890f42a3495c416170a33149b8b243.': 'cluster_9',
#   'aa8337ba45d03bb94206532c8f8fe3d5.': 'cluster_13',
#   '24dc200f780a719b9284f84ac71f07c1.': 'cluster_2',
#   'f39ae106b51614868f1bc7ccfdec3826.': 'cluster_8',
#   'ef737967365cbf8a65f76be0c884fc4c.': 'cluster_8',
#   'f8b69343787e41a8f178fd88b5e7c9a3.': 'cluster_10',
#   '5b94dcc096621efd6a367de3e3d73e9c.': 'cluster_9',
#   'e8416d63b6c15a83c6dbd4349588c0b5.': 'cluster_12',
#   '4348c1152ec8f94c7d93240452a48e5e.': 'cluster_0',
#   '90a3891a50e069f50785fe0449843e9c.': 'cluster_2',
#   '6480282f95bbfb9902d3f4246d8a8884.': 'cluster_2',
#   'a3bcb1bc696bb77e4f78201b107a2229.': 'cluster_0',
#   'cb3f96e4b538a1b75e9999de596aec40.': 'cluster_1',
#   'b4e3eb0a50655cf021d5e2dab384cd28.': 'cluster_9',
#   'bdae535f23ae6198ec7187cccf2c7f76.': 'cluster_14',
#   'edebae2f7d8f67c2a1412a02a9ec0220.': 'cluster_3',
#   '33301f9d6dae748b04d8d03575102947.': 'cluster_13',
#   'e7ee310c4bb0be675b3b79effb2b4e0a.': 'cluster_6',
#   '04b38de2d28aed9eaf7a837c9e269c9c.': 'cluster_3',
#   'a9975390266a82e69532dabdcc3e3fda.': 'cluster_4',
#   '323d0c0d2f5bc3ecdf3616728dbd96f2.': 'cluster_10',
#   'ba50570f33bf98f494e19d7879787664.': 'cluster_6',
#   'f963bd7251198bf9e897603031f25724.': 'cluster_9',
#   'dabcbc1bdf50a9c785d355e68429be0a.': 'cluster_16',
#   '505fdd52ca83335a4d93a1d91bfecdd1.': 'cluster_11',
#   'ce178f510ce657f0cad7def0dad24bab.': 'cluster_2',
#   '9b14ad20260afe252251e580df17e778.': 'cluster_10',
#   'abb8c497cf7677446b19dd1e293eb2c2.': 'cluster_5',
#   '316e193c21eaec9eb0137941e207b5ba.': 'cluster_12',
#   '105340ccee50ddb5e6299d8ec572e598.': 'cluster_12',
#   'f9ab90aa164dc172d578cbbf9a103fec.': 'cluster_12',
#   'eac864a70681149430ae5ea68b756ae6.': 'cluster_10',
#   'dd0f304fc7c7521f3d71d1271a237e25.': 'cluster_5',
#   'f8682eeb69fb2e7bea080391c5fdcb0d.': 'cluster_10',
#   'c77e78eb039cb4fb854002c92970cbaa.': 'cluster_8',
#   '2c580178d4cf35dd294a6cf0e0024460.': 'cluster_0',
#   'ed1ec71e94442686bb91274504be0979.': 'cluster_2',
#   '009ae686ab201cbc03789d40aa89bbc2.': 'cluster_14',
#   '52ef32c08f01c0b4069b869e57c617ed.': 'cluster_6',
#   '21b67b25d35834337bc85889c2dd1ce6.': 'cluster_0',
#   '6206e9833b7101b58e05bfe5edc9f0c8.': 'cluster_5',
#   'bfc1fd0384a12dc206d37f78888df2a6.': 'cluster_14',
#   '32b787c0b89b2497661b97fead93df42.': 'cluster_16',
#   'ff75e58e64f950911ea5faf869170ba0.': 'cluster_2',
#   '7ec4c2137a8a1afb1f32ef8be75c8b1b.': 'cluster_16',
#   '7f051d85b3b866d0b2b4c583c29e0fdd.': 'cluster_13',
#   '292c9baa2347e3199adfb7715832372f.': 'cluster_11',
#   '3545f00afbba4684a7734ff636637f13.': 'cluster_0',
#   '1e4c436b43e85c1387a2b6b4a050be77.': 'cluster_10',
#   '4a6775708fb43ed1a7d6ab1de2cf5e1f.': 'cluster_13',
#   '50e92ae994a329480c8e4817df2d0301.': 'cluster_7',
#   '9d10581de2fa1d91faf499f8d852a7ac.': 'cluster_14',
#   '29fec1b0e9dee28f3a2de0d8ed52a0a2.': 'cluster_0',
#   'f540e0faf891052c2dad7ad4a780b09f.': 'cluster_5',
#   'c9c514db1d050e4c705f9c06d61b181d.': 'cluster_16',
#   '38804b3ac13eae957308c32c0403ff4b.': 'cluster_10',
#   '2be6fab4d76e61a5310688154e8a5207.': 'cluster_14',
#   '9e3cd95ecde2bd45ace3e35ba894bc36.': 'cluster_3',
#   'a131f67a477f55116adfd8520e2aa887.': 'cluster_2',
#   '5d58ddadbae8656e548d5d4db3760740.': 'cluster_12',
#   '478a97808b9baf659e65e21e301147da.': 'cluster_9',
#   'f96e8ee69f04f993bb5fa41004801a8f.': 'cluster_5',
#   'e94e2694d5611d166f709ed6f22ff97f.': 'cluster_13',
#   '04229aa14fedd5de427f25fb50409d5b.': 'cluster_15',
#   '875928557c24b2cbd2c5c138700a9443.': 'cluster_0',
#   '05e96562e19e2fed2b6458f24196f53a.': 'cluster_16',
#   'aa69f293f1ca85a43513ff732978ddd8.': 'cluster_1',
#   'beb641870c3e11dad901eec2d61e92c5.': 'cluster_14',
#   'd66b889983d81e5bd5e9cdb59d2a8483.': 'cluster_1',
#   '37b82c3f62a12c76ebf2ef75aa5336fd.': 'cluster_4',
#   '1c41c2862fc9a86a0a9f4d4f2bc370cc.': 'cluster_2',
#   'd2391783fa8b889b313f630baaba0a05.': 'cluster_12',
#   'f7801d95f48033d45d5887ca08903dd4.': 'cluster_12',
#   '542f1d6263ad49c727d39149f0590b33.': 'cluster_4',
#   'a823104a64da51a1cedd8c5563532715.': 'cluster_14',
#   'e1d0ec26cbd3e7ecec4ca37ea0b66717.': 'cluster_16',
#   '569b346029795185bb747626e2ed278d.': 'cluster_4',
#   '442f98043133734788b35287393a30db.': 'cluster_10',
#   '4c9592165f8dbae97c48b62d459dda59.': 'cluster_5',
#   'e58efff984d9c113a31bb2f17efdd035.': 'cluster_8',
#   'ed5cc73dfda9eee35ff0c6bacae7761e.': 'cluster_2',
#   '462e31e1c98ca5e7dc06ee0b765b29ad.': 'cluster_16',
#   '544206e3b9adaf201e3ab42403beaa40.': 'cluster_3',
#   '45aa71af3617245ddb9c4ab23b443290.': 'cluster_4',
#   '16f1a12b8123d42657938cde7281395f.': 'cluster_4',
#   'aad3cfc8ad630e56a4af7497dee2fee1.': 'cluster_0',
#   '73e26e078017d6c66a1ac2c4b8898e15.': 'cluster_4',
#   'db8e16f27556278b3c3a03447524a77b.': 'cluster_10',
#   '89afef4114bfae49be3be8258fc6016a.': 'cluster_14',
#   '67025a26468fd6481e2fa1aa78110368.': 'cluster_12',
#   '414eca7356f70ec75f8a1fe86329a45e.': 'cluster_11',
#   '7f3894b46a7e116afd0d0c7f30269db9.': 'cluster_13',
#   '92c3ac6358ea30a51969cbf2a38d1816.': 'cluster_5',
#   '2a8a6aaa0e025f7d83290c2b976831d6.': 'cluster_11',
#   'adbb9df0c261558406efcb6bc303f777.': 'cluster_7',
#   'e07824635b9b7fd2d23968ccdebd60ca.': 'cluster_10',
#   'cd9dbb004eb98839ad322f4954f8a6e6.': 'cluster_0',
#   '592331eb5f023d1cc636dea14c90fd3a.': 'cluster_13',
#   '2090151ffb061679014b02ec76e24766.': 'cluster_16',
#   '7e36c2b7e7802c7ce376e2557148488a.': 'cluster_16',
#   '0fcec757bb8499b0f64c9cbdf2992c49.': 'cluster_5',
#   'd43f969bf91c2492f903c834d34d09f3.': 'cluster_10',
#   '2ae3d19eb69945c9a74a704413c48109.': 'cluster_8',
#   '342b8b5f83c29a96c8882fe0c8d9575e.': 'cluster_2',
#   'e9c157ce5012846ce0182547e20d94b0.': 'cluster_10',
#   '5f6efd64c6733543b0de88d187c107d3.': 'cluster_7',
#   '8dbf8a6b73f3839496e613cb0a6e3ece.': 'cluster_9',
#   'e567a9508abfe7508ba27d0172018cf0.': 'cluster_16',
#   'dd9d7835451c693da5d04de10f559e94.': 'cluster_11',
#   'fcee4beb97428b99abaa2d2ea06237b7.': 'cluster_3',
#   '51f792fcf46630673f30219ab9f62d78.': 'cluster_6',
#   '8f3a2588f0eaa527e5391b9fd05a8b5b.': 'cluster_15',
#   '3fc9dcc5b45431cccec27dcd114ea094.': 'cluster_8',
#   'dedacab2f1a95a38edda7cdd82c7df4f.': 'cluster_2',
#   '4400559015c475d78f83c4f900a921fe.': 'cluster_14',
#   '9eac42384a76787e82284e8d94f11168.': 'cluster_1',
#   'c5a5a8ea0cb4eff3a3af38475a9b75dd.': 'cluster_12',
#   '96bb4fb3192fb80dcafe15dc4cd4f917.': 'cluster_5',
#   '24322c050b0c0cfe64ad76dde0d9d065.': 'cluster_10',
#   'c33972f5f01d630f4413ceb0253771c8.': 'cluster_14',
#   'c47e0ed33df74df5355aca3def23a811.': 'cluster_10',
#   '94473b259deb4066b9ce75a191372139.': 'cluster_2',
#   '623285c273d89e18e662d98343d9e33e.': 'cluster_12',
#   'dce4c12303136da116135c6cdda88612.': 'cluster_6',
#   '929790f66dccbbfa03788409df928d5a.': 'cluster_5',
#   '4ab65383062a6390504a4e2dda80bbe2.': 'cluster_2',
#   'b2b429a396caa48854728733fc01b0c4.': 'cluster_11',
#   '8cbc2c2624131aa4d0c88c21ca0e8bda.': 'cluster_11',
#   '11046dda65c3ce2b0283ae87608f1db0.': 'cluster_16',
#   '51045d7ed23422866a6a7e8d7da9c949.': 'cluster_13',
#   '78b7690a656adfb3513b66fda0bc77af.': 'cluster_12',
#   'ba401daef1ae59c99ba4b67445eae8f4.': 'cluster_8',
#   '1517fdbb628f0071761eea83f8bdfc09.': 'cluster_4',
#   '802ebe3b5d5932664f40e0f16338eaa4.': 'cluster_14',
#   '5201babc4e4f7ee9609e739e39788ba6.': 'cluster_11',
#   '59fed2636440af2cdf3f107b2f05397e.': 'cluster_7',
#   'd02e2607234678db6105722b6ba23479.': 'cluster_8',
#   'a7c0f200698f797d3816219f5f6758ac.': 'cluster_6',
#   '55e0f894677e50e088154a583ac93d1e.': 'cluster_12',
#   '5f947e6675316d7e19b54cd199e4da4b.': 'cluster_11',
#   '02a423659dda5751a1c707a3639bb51f.': 'cluster_13',
#   'ea83b5954dc98f403d74d38e3401cad1.': 'cluster_4',
#   'e89088fd0ce6b01829a2419a65c3b2b1.': 'cluster_1',
#   '3d9c3c0e9b3926e3165dc3b1fea506bf.': 'cluster_6',
#   '955808f3498c9fa51924cc95eaed7e15.': 'cluster_12',
#   '06d95f3c880d15c7d477b2e44d5414c2.': 'cluster_8',
#   '8ddb7b9b389e7645bcfc3ec4b6379265.': 'cluster_10',
#   '809b45fcdddd040180696d916d165d04.': 'cluster_0',
#   '8953db01557146b7fc4509dc1f3ac190.': 'cluster_10',
#   '29a3307c6a3337b573f46b1540bfd5eb.': 'cluster_10',
#   'a25a258adb4566bdd1348d6855233746.': 'cluster_10',
#   '3489d1b5cd6f509d388c50dfeb68fdc0.': 'cluster_16',
#   'd44baac46790411799d69f899c5c331b.': 'cluster_16',
#   'd07c4911ceafbe5db3f51a5ae2bbeba4.': 'cluster_2',
#   '1cb304ddc5613dfd495f675c3580c665.': 'cluster_13',
#   'cdd1afe7112104dc45e43a8eab8f56fd.': 'cluster_11',
#   '528330593a196b6e3a061372645648e3.': 'cluster_2',
#   '167c57a595fccf6ca5a2e353379b864c.': 'cluster_7',
#   '731bf596b748629d95e1033d3be08634.': 'cluster_4',
#   '2e26a5357d9ede57aaddc1565dbd28b6.': 'cluster_1',
#   'fd3695c58d9d14982ed81e9c7e9410fa.': 'cluster_14',
#   '0121968e60ef6b1d019f33de3c29dbce.': 'cluster_16',
#   'cd98660b02d4653538b4264e66a03dfd.': 'cluster_10',
#   '5bb2ab3c7721a53e86ab82a798d13f45.': 'cluster_13',
#   'e55ae5116bc4f92d7beefc5b14d207e9.': 'cluster_16',
#   '0858bc389b91c53a4b9a513aeb62be78.': 'cluster_5',
#   'e0a622d3bafde3a827f4216f0e6891b3.': 'cluster_9',
#   'd2b422d868ca87ed2889703a9fdad636.': 'cluster_10',
#   'b14d062559096a09b09cc8c7565c5a46.': 'cluster_1',
#   'f2e447a8a7070ed0f91380dabe295475.': 'cluster_10',
#   'd0a0f7ba4df52421801caa0a6d261fac.': 'cluster_4',
#   'a46eb4eeb30f41c1877246db6960f5dd.': 'cluster_9',
#   '11813c8e4bddbbe6cf3db3996c5750f3.': 'cluster_0',
#   '0306e1882e336f5d0dd21b6be4c8fdc0.': 'cluster_9',
#   '728f3e9ed96b61936dc127357dbc2086.': 'cluster_16',
#   '5f0fa188f07f465be0885aabe09861ca.': 'cluster_16',
#   'fefdbb0f4b1a7e4e942c3df9bb9d580a.': 'cluster_5',
#   '37de9b77126b31220d134b033c4310e1.': 'cluster_9',
#   'b6471cf1578ab01c5fa489cd31355ebe.': 'cluster_4',
#   '5a993279e6abb1b88fe859f310a6abf9.': 'cluster_5',
#   'e7ef9425e411f2f2b774feb2aa13a01c.': 'cluster_5',
#   '31c9c97832d5dcba935cecd95390ab0c.': 'cluster_6',
#   '06421deaea221ac8ec7ab5734adb5b01.': 'cluster_15',
#   '33ff3fc8508db140a665acb20c3f5f29.': 'cluster_5',
#   'fbcd9214b10e74d5ec8b4687084afc78.': 'cluster_4',
#   'a8d8a58a799cd0d5298ff805adddd4cd.': 'cluster_10',
#   '827ddaab64c6e6883a1edfc5cd9ada51.': 'cluster_14',
#   '6c878d335208ba7ee3172f8e226a555e.': 'cluster_11',
#   '6ce736f8680bdc40884fed47c3328718.': 'cluster_13',
#   'f7c8faccfa654f5415027d0b53c9c289.': 'cluster_8',
#   'b0a5a06cc6e7ab098096cc8c24d4c213.': 'cluster_16',
#   '3c3473137bba879ac6935f44c843598e.': 'cluster_12',
#   '3e976ed8eec7a2fed3201641ea397892.': 'cluster_15',
#   '7a1c9899a4724599b833a97dbd468ee0.': 'cluster_16',
#   '10734a78b41531d43190d6ccddd1a6db.': 'cluster_9',
#   'df24718ec60f232c4169e2637fb8e1c2.': 'cluster_2',
#   '8adf248a2da11f57dd67afc0146f6a25.': 'cluster_8',
#   '4ac64881aacf6c4d1a53083ead040309.': 'cluster_9',
#   '05f5d0367eada6f82affd0e9ddad830f.': 'cluster_15',
#   'dedcbd66b5143ee75567a11d109441b4.': 'cluster_4',
#   '69a9ab49e9f484fa8eed28f47b9c4a19.': 'cluster_16',
#   'f0646b41a2b08b12093b4028914395ac.': 'cluster_2',
#   'ec21736a67a68366ac663509359b7c5a.': 'cluster_12',
#   '1babf4d02b82740ef69faf94d3519029.': 'cluster_2',
#   'bc1dcfe1372f4f0f7692c7108cc9eff5.': 'cluster_9',
#   '879fc26b7fc361fff6bc7681ba235ad3.': 'cluster_7',
#   '0ad48f253bb1dbb7b9e17d71c27261e7.': 'cluster_12'}}

# %%
import json
file_path = "test_results.json"

# Write dictionary to JSON file
with open(file_path, "w") as json_file:
    json.dump(result, json_file, indent=4)

print(f"Dictionary saved to {file_path}")
# Out:
# Dictionary saved to test_results.json

# %%
len(result['samples'])
# Out:
# 280

# %%
# loader = JSONLoader(
#     file_path='test.json',
#     jq_schema=".ocr[].text",
#     text_content=False)
#
# data = loader.load()
# print(f'document count: {len(data)}')
# data

# %%
# # Load the vectorstore
# faiss_index = FAISS.from_documents(data_full_text, embeddings)
# faiss_index.save_local("faiss_index")
# faiss_db = FAISS.load_local("faiss_index", embeddings, allow_dangerous_deserialization=True)

# %%
# from sklearn.manifold import TSNE
# import matplotlib.pyplot as plt
#
# # Taking out the warnings
# import warnings
# from warnings import simplefilter
#
# # Filter out FutureWarnings
# simplefilter(action='ignore', category=FutureWarning)
#
# # Perform t-SNE and reduce to 2 dimensions
# tsne = TSNE(n_components=2, random_state=42)
# reduced_data_tsne = tsne.fit_transform(vectors)
#
# # Plot the reduced data
# plt.scatter(reduced_data_tsne[:, 0], reduced_data_tsne[:, 1], c=kmeans.labels_)
# plt.xlabel('Dimension 1')
# plt.ylabel('Dimension 2')
# plt.title('Book Embeddings Clustered')
# plt.show()
